# %% [markdown]
# # Intraday Strategy, Part 2: Model Training & Signal Evaluation

# %% [markdown]
# In this notebook, we load the high-quality NASDAQ100 minute-bar trade-and-quote data generously provided by [Algoseek](https://www.algoseek.com/) (available [here](https://www.algoseek.com/ml4t-book-data.html)) and use the features engineered in the last notebook to train gradient boosting model that predicts the returns for the NASDAQ100 stocks over the next 1-minute bar.
#
# > Note that we will assume throughout that we can always buy (sell) at the first (last) trade price for a given bar at no cost and without market impact. This does certainly not reflect market reality, and is rather due to the challenges of simulating a trading strategy at this much higher intraday frequency in a realistic manner using open-source tools.
#
# Note also that this section has slightly changed from the version published in the book to permit replication using the Algoseek data sample.

# %%
# %sudo apt install cmake
# %pip install lightgbm --config-setting=cmake.define.USE_CUDA=ON 
# %pip install tables

# %%
# https://docs.cupy.dev/en/stable/install.html#installing-cupy
# %pip install --extra-index-url https://pypi.nvidia.com cupy-cuda12x cudf-cu12 "dask[complete]"

# %%
# %load_ext cython

# %%
from dask.distributed import Client

client = Client("tcp://127.0.0.1:43581")
client

# %%
# from dask.distributed import Client, LocalCluster
# cluster = LocalCluster()
# client = Client(cluster)
# client = Client.current()
# client = Client()
# client

# client = Client(n_workers=1, 
#                 threads_per_worker=1,
#                 memory_limit='70GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:39319' processes=4 threads=16, memory=78.38 GiB>

# %%
print(client.cluster)
# Out:
# None

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

import sys, os
from pathlib import Path
from time import time
from tqdm import tqdm

import numpy as np
import pandas as pd

import lightgbm as lgb

import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns

# %%
def format_time(t):
    """Return a formatted time string 'HH:MM:SS
    based on a numeric time() value"""
    m, s = divmod(t, 60)
    h, m = divmod(m, 60)
    return f'{h:0>2.0f}:{m:0>2.0f}:{s:0>2.0f}'

# %%
sns.set_style('whitegrid')
idx = pd.IndexSlice
deciles = np.arange(.1, 1, .1)

# %%
# where we stored the features engineered in the previous notebook
data_store = '../data/nasdaq100/algoseek-longer.h5'

# %%
# where we'll store the model results
result_store = 'results/longer-intraday.h5'

# %%
# here we save the trained models
model_path = Path('models/longer-intraday')
if not model_path.exists():
    model_path.mkdir(parents=True)

# %% [markdown]
# ## Load Model Data

# %%
data = pd.read_hdf(data_store, 'model_data')

# %%
data.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 13452358 entries, ('AAL', Timestamp('2015-01-02 09:30:00')) to ('YHOO', Timestamp('2017-06-16 12:20:00'))
# Data columns (total 23 columns):
#  #   Column          Non-Null Count     Dtype
# ---  ------          --------------     -----
#  0   minute          13452358 non-null  int64
#  1   ret1min         13350557 non-null  float64
#  2   ret2min         13180747 non-null  float64
#  3   ret3min         13102981 non-null  float64
#  4   ret4min         13025556 non-null  float64
#  5   ret5min         12949249 non-null  float64
#  6   ret6min         12871879 non-null  float64
#  7   ret7min         12793437 non-null  float64
#  8   ret8min         12715802 non-null  float64
#  9   ret9min         12638377 non-null  float64
#  10  ret10min        12560968 non-null  float64
#  11  retwin          12560968 non-null  float64
#  12  fwdwin          13452358 non-null  float64
#  13  rup             13139376 non-null  float64
#  14  rdown           13139376 non-null  float64
#  15  BOP             13350557 non-null  float64
#  16  CCI             12488035 non-null  float64
#  17  MFI             13450459 non-null  float64
#  18  STOCHRSI        13448413 non-null  float64
#  19  slowd           13450050 non-null  float64
#  20  slowk           13450050 non-null  float64
#  21  NATR            13450459 non-null  float64
#  22  trades_bid_ask  13139376 non-null  float64
# dtypes: float64(22), int64(1)
# memory usage: 2.4+ GB

# %%
data.sample(frac=.1).describe(percentiles=np.arange(.1, 1, .1))
# Out:
#              minute       ret1min       ret2min       ret3min       ret4min  \
# count  1.345236e+06  1.335162e+06  1.318171e+06  1.310293e+06  1.302459e+06
# mean   8.476032e+01 -5.331611e-06 -5.024607e-06 -4.908440e-06 -5.524137e-06
# std    4.928894e+01  1.078523e-03  1.457604e-03  1.724937e-03  1.974202e-03
# min    0.000000e+00 -9.274689e-02 -8.867392e-02 -9.588042e-02 -1.354293e-01
# 10%    1.700000e+01 -9.606148e-04 -1.342494e-03 -1.635769e-03 -1.881548e-03
# 20%    3.400000e+01 -5.311380e-04 -7.637086e-04 -9.372289e-04 -1.076817e-03
# 30%    5.100000e+01 -2.991325e-04 -4.347826e-04 -5.364447e-04 -6.210078e-04
# 40%    6.800000e+01 -1.292818e-04 -1.987281e-04 -2.466091e-04 -2.869163e-04
# 50%    8.500000e+01  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 60%    1.020000e+02  1.226242e-04  1.886792e-04  2.337541e-04  2.683858e-04
# 70%    1.190000e+02  2.913555e-04  4.240882e-04  5.216484e-04  6.038582e-04
# 80%    1.360000e+02  5.201469e-04  7.527975e-04  9.229349e-04  1.061433e-03
# 90%    1.530000e+02  9.456138e-04  1.332346e-03  1.626545e-03  1.869936e-03
# max    1.700000e+02  1.006452e-01  1.333333e-01  8.547368e-02  1.334802e-01
#
#             ret5min       ret6min       ret7min       ret8min       ret9min  \
# count  1.294702e+06  1.286996e+06  1.279151e+06  1.271391e+06  1.263617e+06
# mean  -5.835810e-06 -6.643447e-06 -6.041517e-06 -6.193854e-06 -7.564423e-06
# std    2.179971e-03  2.376928e-03  2.517169e-03  2.671626e-03  2.808259e-03
# min   -1.507981e-01 -1.757200e-01 -2.063684e-01 -2.180095e-01 -2.368217e-01
# 10%   -2.094241e-03 -2.288230e-03 -2.467004e-03 -2.619383e-03 -2.770083e-03
# 20%   -1.198720e-03 -1.307190e-03 -1.412208e-03 -1.505351e-03 -1.593174e-03
# 30%   -6.907354e-04 -7.552870e-04 -8.139219e-04 -8.718396e-04 -9.235328e-04
# 40%   -3.181674e-04 -3.460208e-04 -3.708776e-04 -3.976821e-04 -4.217630e-04
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 60%    3.003294e-04  3.278689e-04  3.522348e-04  3.741631e-04  3.972695e-04
# 70%    6.714789e-04  7.329587e-04  7.928118e-04  8.477892e-04  8.996851e-04
# 80%    1.178319e-03  1.285888e-03  1.388405e-03  1.481921e-03  1.571468e-03
# 90%    2.079428e-03  2.268722e-03  2.442473e-03  2.599596e-03  2.747605e-03
# max    1.852018e-01  2.006452e-01  9.195402e-02  1.112655e-01  1.213363e-01
#
#        ...           rup         rdown           BOP           CCI  \
# count  ...  1.314158e+06  1.314158e+06  1.335162e+06  1.248820e+06
# mean   ...  4.953434e-01  4.874023e-01 -2.836628e-03  7.421342e-02
# std    ...  1.548672e+01  7.245625e+00  6.263116e-01  1.099725e+02
# min    ...  0.000000e+00  0.000000e+00 -1.000000e+00 -4.666667e+02
# 10%    ...  0.000000e+00  0.000000e+00 -8.888889e-01 -1.369431e+02
# 20%    ...  1.027397e-01  1.080192e-01 -6.662459e-01 -9.967235e+01
# 30%    ...  1.966965e-01  2.033219e-01 -4.500000e-01 -6.939431e+01
# 40%    ...  2.781710e-01  2.869127e-01 -2.000000e-01 -3.741999e+01
# 50%    ...  3.564159e-01  3.660061e-01  0.000000e+00  1.609170e-01
# 60%    ...  4.383216e-01  4.480287e-01  1.904762e-01  3.758673e+01
# 70%    ...  5.283634e-01  5.370587e-01  4.400000e-01  6.926264e+01
# 80%    ...  6.452401e-01  6.520118e-01  6.571429e-01  9.933995e+01
# 90%    ...  8.231070e-01  8.265420e-01  8.879133e-01  1.368466e+02
# max    ...  1.500000e+04  6.428571e+03  1.000000e+00  4.666667e+02
#
#                 MFI      STOCHRSI         slowd         slowk          NATR  \
# count  1.345048e+06  1.344850e+06  1.345013e+06  1.345013e+06  1.345048e+06
# mean   4.997792e+01  4.990156e+01  5.017276e+01  5.016970e+01  1.249302e-01
# std    1.997392e+01  3.560624e+01  2.797171e+01  2.883433e+01  1.002415e-01
# min   -4.948145e-10  0.000000e+00 -3.129941e-12 -3.330077e-12  1.844370e-03
# 10%    2.349932e+01  0.000000e+00  1.213553e+01  1.095503e+01  5.265029e-02
# 20%    3.195763e+01  9.438197e+00  2.044818e+01  1.944444e+01  6.470472e-02
# 30%    3.850552e+01  2.327578e+01  2.954885e+01  2.888889e+01  7.601244e-02
# 40%    4.435694e+01  3.652090e+01  3.956150e+01  3.921569e+01  8.795438e-02
# 50%    4.990677e+01  4.984269e+01  5.017551e+01  5.002501e+01  1.016236e-01
# 60%    5.547779e+01  6.314639e+01  6.079428e+01  6.111111e+01  1.180857e-01
# 70%    6.134895e+01  7.647258e+01  7.080237e+01  7.144852e+01  1.390749e-01
# 80%    6.800980e+01  9.036421e+01  7.994380e+01  8.094768e+01  1.693546e-01
# 90%    7.662366e+01  1.000000e+02  8.821296e+01  8.938089e+01  2.218208e-01
# max    1.000000e+02  1.000000e+02  1.000000e+02  1.000000e+02  3.758063e+01
#
#        trades_bid_ask
# count    1.314158e+06
# mean    -1.842092e-02
# std      1.119081e+01
# min     -4.000000e+03
# 10%     -6.900946e-01
# 20%     -4.341919e-01
# 30%     -2.637047e-01
# 40%     -1.260455e-01
# 50%     -1.367989e-03
# 60%      9.236533e-02
# 70%      2.312734e-01
# 80%      4.022334e-01
# 90%      6.644518e-01
# max      8.796000e+03
#
# [14 rows x 23 columns]

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Helper functions

# %%
def get_fi(model):
    fi = model.feature_importance(importance_type='gain')
    return (pd.Series(fi / fi.sum(),
                      index=model.feature_name()))

# %% [markdown]
# ### Categorical Variables

# %%
data['stock_id'], ticker_to_id = pd.factorize(data.index.get_level_values('ticker'), sort=True)
ticker_to_id
# Out:
# Index(['AAL', 'AAPL', 'ADBE', 'ADI', 'ADP', 'ADSK', 'AKAM', 'ALGN', 'ALTR',
#        'ALXN',
#        ...
#        'VRSK', 'VRTX', 'WBA', 'WDAY', 'WDC', 'WFM', 'WYNN', 'XLNX', 'XRAY',
#        'YHOO'],
#       dtype='object', length=142)

# %%
ticker_to_id[3]
# Out:
# 'ADI'

# %%
categoricals = ['stock_id']

# %%
data['stock_id']
# Out:
# ticker  date_time
# AAL     2015-01-02 09:30:00      0
#         2015-01-02 09:31:00      0
#         2015-01-02 09:32:00      0
#         2015-01-02 09:33:00      0
#         2015-01-02 09:34:00      0
#                               ...
# YHOO    2017-06-16 12:16:00    141
#         2017-06-16 12:17:00    141
#         2017-06-16 12:18:00    141
#         2017-06-16 12:19:00    141
#         2017-06-16 12:20:00    141
# Name: stock_id, Length: 13452358, dtype: int64

# %% [markdown]
# ### Custom Metric

# %%
import cupy

cupy.cuda.get_device_id()
# Out:
# 0

# %%
# We really only care about picking the top k stocks rather than ranking the whole list of predicted returns.  
# But a feature we get from ranking the list is the low confidence when there are relative few distinct values.

# %%
import cudf


def spearmanr(preds: np.ndarray, labels: np.ndarray):
    """Custom IC eval metric for lightgbm"""
    t_preds = cudf.Series(preds)
    t_labels = cudf.Series(labels)
    return t_preds.corr(t_labels)


def ic_lgbm(preds: np.ndarray, train_data: np.ndarray):
    """Custom IC eval metric for lightgbm"""
    return 'ic', spearmanr(preds, train_data.get_label()), True # is_higher_better

# %%
# n_preds = np.array(list(range(1.0, 11.0)))
# n_labels = np.array(list(range(1.0, 11.0)))
n_preds = np.arange(11.0)
n_labels = lgb.Dataset(data= np.arange(11.0), label= np.arange(11.0))
ic_lgbm(n_preds, n_labels)
# Out:
# ('ic', 1.0, True)

# %% [markdown]
# ### Cross-validation setup

# %%
data
# Out:
#                             minute   ret1min   ret2min   ret3min   ret4min  \
# ticker date_time
# AAL    2015-01-02 09:30:00       0  0.004241       NaN       NaN       NaN
#        2015-01-02 09:31:00       1 -0.007896 -0.003688       NaN       NaN
#        2015-01-02 09:32:00       2  0.005552 -0.002387  0.001844       NaN
#        2015-01-02 09:33:00       3 -0.006072 -0.000185 -0.008079 -0.003872
#        2015-01-02 09:34:00       4  0.007773  0.001840  0.007773 -0.000184
# ...                            ...       ...       ...       ...       ...
# YHOO   2017-06-16 12:16:00     166 -0.000191  0.000000 -0.000191 -0.000955
#        2017-06-16 12:17:00     167  0.000000 -0.000191  0.000000 -0.000191
#        2017-06-16 12:18:00     168 -0.000189 -0.000381 -0.000572 -0.000381
#        2017-06-16 12:19:00     169 -0.000765 -0.000861 -0.001052 -0.001243
#        2017-06-16 12:20:00     170 -0.000574 -0.001052 -0.001148 -0.001339
#
#                              ret5min   ret6min   ret7min   ret8min   ret9min  \
# ticker date_time
# AAL    2015-01-02 09:30:00       NaN       NaN       NaN       NaN       NaN
#        2015-01-02 09:31:00       NaN       NaN       NaN       NaN       NaN
#        2015-01-02 09:32:00       NaN       NaN       NaN       NaN       NaN
#        2015-01-02 09:33:00       NaN       NaN       NaN       NaN       NaN
#        2015-01-02 09:34:00  0.004057       NaN       NaN       NaN       NaN
# ...                              ...       ...       ...       ...       ...
# YHOO   2017-06-16 12:16:00 -0.000382 -0.000287 -0.000765  0.000383  0.001339
#        2017-06-16 12:17:00 -0.000955 -0.000382 -0.000287 -0.000765  0.000383
#        2017-06-16 12:18:00 -0.000572 -0.001336 -0.000763 -0.000667 -0.001145
#        2017-06-16 12:19:00 -0.001052 -0.001243 -0.002006 -0.001434 -0.001339
#        2017-06-16 12:20:00 -0.001530 -0.001339 -0.001530 -0.002293 -0.001721
#
#                             ...     rdown       BOP         CCI        MFI  \
# ticker date_time            ...
# AAL    2015-01-02 09:30:00  ...  0.088409  0.522727         NaN        NaN
#        2015-01-02 09:31:00  ...  0.605885 -0.860000         NaN        NaN
#        2015-01-02 09:32:00  ...  0.248803  0.857143         NaN        NaN
#        2015-01-02 09:33:00  ...  0.515424 -0.942857         NaN        NaN
#        2015-01-02 09:34:00  ...  0.107958  0.954545         NaN        NaN
# ...                         ...       ...       ...         ...        ...
# YHOO   2017-06-16 12:16:00  ...  0.538025 -0.400000   21.294270  47.893392
#        2017-06-16 12:17:00  ...  0.533146  0.000000   20.159449  45.607851
#        2017-06-16 12:18:00  ...  0.297138 -0.495000   -6.129079  46.794833
#        2017-06-16 12:19:00  ...  0.662231 -0.800000  -73.104392  44.782144
#        2017-06-16 12:20:00  ...  0.947009 -0.750000 -139.704904  47.583519
#
#                              STOCHRSI      slowd      slowk      NATR  \
# ticker date_time
# AAL    2015-01-02 09:30:00        NaN        NaN        NaN       NaN
#        2015-01-02 09:31:00        NaN        NaN        NaN       NaN
#        2015-01-02 09:32:00        NaN        NaN        NaN       NaN
#        2015-01-02 09:33:00        NaN        NaN        NaN       NaN
#        2015-01-02 09:34:00        NaN        NaN        NaN       NaN
# ...                               ...        ...        ...       ...
# YHOO   2017-06-16 12:16:00  64.340973  81.587302  77.142857  0.084162
#        2017-06-16 12:17:00  64.340973  77.777778  75.238095  0.083615
#        2017-06-16 12:18:00  49.906199  73.339683  67.638095  0.080406
#        2017-06-16 12:19:00  26.633135  66.679365  57.161905  0.081551
#        2017-06-16 12:20:00   0.000000  55.985434  43.156303  0.081220
#
#                             trades_bid_ask  stock_id
# ticker date_time
# AAL    2015-01-02 09:30:00       -0.302649         0
#        2015-01-02 09:31:00       -0.529680         0
#        2015-01-02 09:32:00        0.470287         0
#        2015-01-02 09:33:00       -0.390279         0
#        2015-01-02 09:34:00        0.625711         0
# ...                                    ...       ...
# YHOO   2017-06-16 12:16:00       -0.160143       141
#        2017-06-16 12:17:00        0.053432       141
#        2017-06-16 12:18:00        0.457570       141
#        2017-06-16 12:19:00       -0.269353       141
#        2017-06-16 12:20:00       -0.326159       141
#
# [13452358 rows x 24 columns]

# %%
data.index.levels
# Out:
# FrozenList([['AAL', 'AAPL', 'ADBE', 'ADI', 'ADP', 'ADSK', 'AKAM', 'ALGN', 'ALTR', 'ALXN', 'AMAT', 'AMGN', 'AMZN', 'ASML', 'ATVI', 'AVGO', 'BATRA', 'BATRK', 'BBBY', 'BIDU', 'BIIB', 'BMRN', 'BRCM', 'CA', 'CDNS', 'CELG', 'CERN', 'CHKP', 'CHRW', 'CHTR', 'CMCSA', 'CMCSK', 'COST', 'CSCO', 'CSX', 'CTAS', 'CTRP', 'CTRX', 'CTSH', 'CTXS', 'DISCA', 'DISCK', 'DISH', 'DLTR', 'DTV', 'EA', 'EBAY', 'ENDP', 'EQIX', 'ESRX', 'EXPD', 'EXPE', 'FAST', 'FB', 'FISV', 'FOX', 'FOXA', 'GILD', 'GMCR', 'GOOG', 'GOOGL', 'GRMN', 'HAS', 'HOLX', 'HSIC', 'IDXX', 'ILMN', 'INCY', 'INTC', 'INTU', 'ISRG', 'JBHT', 'JD', 'KHC', 'KLAC', 'KRFT', 'LBTYA', 'LBTYK', 'LILA', 'LILAK', 'LLTC', 'LMCA', 'LMCK', 'LRCX', 'LVNTA', 'MAR', 'MAT', 'MCHP', 'MDLZ', 'MELI', 'MNST', 'MSFT', 'MU', 'MXIM', 'MYL', 'NCLH', 'NFLX', 'NTAP', 'NTES', 'NVDA', ...], [2015-01-02 09:30:00, 2015-01-02 09:31:00, 2015-01-02 09:32:00, 2015-01-02 09:33:00, 2015-01-02 09:34:00, 2015-01-02 09:35:00, 2015-01-02 09:36:00, 2015-01-02 09:37:00, 2015-01-02 09:38:00, 2015-01-02 09:39:00, 2015-01-02 09:40:00, 2015-01-02 09:41:00, 2015-01-02 09:42:00, 2015-01-02 09:43:00, 2015-01-02 09:44:00, 2015-01-02 09:45:00, 2015-01-02 09:46:00, 2015-01-02 09:47:00, 2015-01-02 09:48:00, 2015-01-02 09:49:00, 2015-01-02 09:50:00, 2015-01-02 09:51:00, 2015-01-02 09:52:00, 2015-01-02 09:53:00, 2015-01-02 09:54:00, 2015-01-02 09:55:00, 2015-01-02 09:56:00, 2015-01-02 09:57:00, 2015-01-02 09:58:00, 2015-01-02 09:59:00, 2015-01-02 10:00:00, 2015-01-02 10:01:00, 2015-01-02 10:02:00, 2015-01-02 10:03:00, 2015-01-02 10:04:00, 2015-01-02 10:05:00, 2015-01-02 10:06:00, 2015-01-02 10:07:00, 2015-01-02 10:08:00, 2015-01-02 10:09:00, 2015-01-02 10:10:00, 2015-01-02 10:11:00, 2015-01-02 10:12:00, 2015-01-02 10:13:00, 2015-01-02 10:14:00, 2015-01-02 10:15:00, 2015-01-02 10:16:00, 2015-01-02 10:17:00, 2015-01-02 10:18:00, 2015-01-02 10:19:00, 2015-01-02 10:20:00, 2015-01-02 10:21:00, 2015-01-02 10:22:00, 2015-01-02 10:23:00, 2015-01-02 10:24:00, 2015-01-02 10:25:00, 2015-01-02 10:26:00, 2015-01-02 10:27:00, 2015-01-02 10:28:00, 2015-01-02 10:29:00, 2015-01-02 10:30:00, 2015-01-02 10:31:00, 2015-01-02 10:32:00, 2015-01-02 10:33:00, 2015-01-02 10:34:00, 2015-01-02 10:35:00, 2015-01-02 10:36:00, 2015-01-02 10:37:00, 2015-01-02 10:38:00, 2015-01-02 10:39:00, 2015-01-02 10:40:00, 2015-01-02 10:41:00, 2015-01-02 10:42:00, 2015-01-02 10:43:00, 2015-01-02 10:44:00, 2015-01-02 10:45:00, 2015-01-02 10:46:00, 2015-01-02 10:47:00, 2015-01-02 10:48:00, 2015-01-02 10:49:00, 2015-01-02 10:50:00, 2015-01-02 10:51:00, 2015-01-02 10:52:00, 2015-01-02 10:53:00, 2015-01-02 10:54:00, 2015-01-02 10:55:00, 2015-01-02 10:56:00, 2015-01-02 10:57:00, 2015-01-02 10:58:00, 2015-01-02 10:59:00, 2015-01-02 11:00:00, 2015-01-02 11:01:00, 2015-01-02 11:02:00, 2015-01-02 11:03:00, 2015-01-02 11:04:00, 2015-01-02 11:05:00, 2015-01-02 11:06:00, 2015-01-02 11:07:00, 2015-01-02 11:08:00, 2015-01-02 11:09:00, ...]])

# %%
data.index.get_level_values(1)
# Out:
# DatetimeIndex(['2015-01-02 09:30:00', '2015-01-02 09:31:00',
#                '2015-01-02 09:32:00', '2015-01-02 09:33:00',
#                '2015-01-02 09:34:00', '2015-01-02 09:35:00',
#                '2015-01-02 09:36:00', '2015-01-02 09:37:00',
#                '2015-01-02 09:38:00', '2015-01-02 09:39:00',
#                ...
#                '2017-06-16 12:11:00', '2017-06-16 12:12:00',
#                '2017-06-16 12:13:00', '2017-06-16 12:14:00',
#                '2017-06-16 12:15:00', '2017-06-16 12:16:00',
#                '2017-06-16 12:17:00', '2017-06-16 12:18:00',
#                '2017-06-16 12:19:00', '2017-06-16 12:20:00'],
#               dtype='datetime64[ns]', name='date_time', length=13452358, freq=None)

# %%
data.index.get_level_values(1).min().date(), data.index.get_level_values(1).max().date()
# Out:
# (datetime.date(2015, 1, 2), datetime.date(2017, 12, 29))

# %%
data.index.get_level_values(1)[data.index.get_level_values(1).date == data.index.get_level_values(1).min().date()]
# Out:
# DatetimeIndex(['2015-01-02 09:30:00', '2015-01-02 09:31:00',
#                '2015-01-02 09:32:00', '2015-01-02 09:33:00',
#                '2015-01-02 09:34:00', '2015-01-02 09:35:00',
#                '2015-01-02 09:36:00', '2015-01-02 09:37:00',
#                '2015-01-02 09:38:00', '2015-01-02 09:39:00',
#                ...
#                '2015-01-02 12:11:00', '2015-01-02 12:12:00',
#                '2015-01-02 12:13:00', '2015-01-02 12:14:00',
#                '2015-01-02 12:15:00', '2015-01-02 12:16:00',
#                '2015-01-02 12:17:00', '2015-01-02 12:18:00',
#                '2015-01-02 12:19:00', '2015-01-02 12:20:00'],
#               dtype='datetime64[ns]', name='date_time', length=17691, freq=None)

# %%
data_by_date = data.reorder_levels(["date_time", "ticker"])
data_by_date.sort_index(inplace=True)

# %%
from datetime import datetime, timedelta

# %%
date_time_values = data_by_date.index.get_level_values('date_time')
data_dates = np.unique(date_time_values.date)
data_date_times = sorted(pd.to_datetime(data_dates))

# %%
first_day_of_months = sorted(pd.to_datetime(data_dates).to_period('M').start_time.unique())

# Add the first day of the next month to close the last interval
month_breaks = first_day_of_months + [first_day_of_months[-1] + pd.offsets.MonthBegin()]

# # Create the IntervalIndex for months, closed on the left
# monthly_intervals = pd.IntervalIndex.from_breaks(month_breaks, closed='left')

# # Step 4: Map 'date_time' to monthly intervals
# month_intervals = pd.cut(date_time_values, bins=monthly_intervals)
# month_intervals

# %%
# Create intervals based on unique dates (non-contiguous) with closed='left'
day_interval_index = pd.IntervalIndex.from_breaks(data_date_times + [data_date_times[-1] + pd.Timedelta(days=1)], closed='left')
# Map 'date_time' to these intervals
per_date_intervals = pd.cut(date_time_values, bins=day_interval_index)

# Create the IntervalIndex for months, closed on the left
month_interval_index = pd.IntervalIndex.from_breaks(month_breaks, closed='left')
# Map 'date_time' to monthly intervals
per_month_intervals = pd.cut(date_time_values, bins=month_interval_index)

# Create a new MultiIndex with intervals instead of date_time
# new_index = pd.MultiIndex.from_arrays([per_month_intervals, per_date_intervals, date_time_values, data_by_date.index.get_level_values('ticker')], 
#                                       names=['per_month_interval', 'per_date_interval', 'date_time', 'ticker'])
# new_index = pd.MultiIndex.from_arrays([per_month_intervals, date_time_values, data_by_date.index.get_level_values('ticker')], 
#                                       names=['per_month_interval', 'date_time', 'ticker'])
# new_index

# %%
# Step 5: Assign this new index back to the DataFrame
data_by_date_interval = data_by_date.copy()
data_by_date_interval.index = pd.MultiIndex.from_arrays([per_month_intervals, date_time_values, data_by_date.index.get_level_values('ticker')],
                                                        names=['per_month_interval', 'date_time', 'ticker'])

# Step 6: Optionally, sort the DataFrame by the new index (if needed)
data_by_date_interval.sort_index(inplace=True)
data_by_date_interval.reset_index(level='ticker', drop=True, inplace=True)
data_by_date_interval
# Out:
#                                                                 minute  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00       0
#                                            2015-01-02 09:30:00       0
#                                            2015-01-02 09:30:00       0
#                                            2015-01-02 09:30:00       0
#                                            2015-01-02 09:30:00       0
# ...                                                                ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00     170
#                                            2017-12-29 12:20:00     170
#                                            2017-12-29 12:20:00     170
#                                            2017-12-29 12:20:00     170
#                                            2017-12-29 12:20:00     170
#
#                                                                  ret1min  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00  0.004241
#                                            2015-01-02 09:30:00 -0.001347
#                                            2015-01-02 09:30:00  0.001100
#                                            2015-01-02 09:30:00  0.000000
#                                            2015-01-02 09:30:00  0.003615
# ...                                                                  ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  0.000000
#                                            2017-12-29 12:20:00  0.000455
#                                            2017-12-29 12:20:00 -0.000270
#                                            2017-12-29 12:20:00  0.000074
#                                            2017-12-29 12:20:00 -0.000301
#
#                                                                  ret2min  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
# ...                                                                  ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  0.000274
#                                            2017-12-29 12:20:00  0.000367
#                                            2017-12-29 12:20:00  0.000205
#                                            2017-12-29 12:20:00  0.000221
#                                            2017-12-29 12:20:00 -0.000226
#
#                                                                  ret3min  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
# ...                                                                  ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  0.000549
#                                            2017-12-29 12:20:00 -0.000171
#                                            2017-12-29 12:20:00 -0.000211
#                                            2017-12-29 12:20:00 -0.000147
#                                            2017-12-29 12:20:00 -0.000226
#
#                                                                  ret4min  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
# ...                                                                  ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  0.000513
#                                            2017-12-29 12:20:00 -0.000046
#                                            2017-12-29 12:20:00  0.000205
#                                            2017-12-29 12:20:00  0.000000
#                                            2017-12-29 12:20:00       NaN
#
#                                                                  ret5min  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
# ...                                                                  ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  0.000123
#                                            2017-12-29 12:20:00  0.000069
#                                            2017-12-29 12:20:00 -0.000033
#                                            2017-12-29 12:20:00  0.000141
#                                            2017-12-29 12:20:00  0.000301
#
#                                                                  ret6min  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
# ...                                                                  ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00 -0.000137
#                                            2017-12-29 12:20:00 -0.000109
#                                            2017-12-29 12:20:00 -0.000033
#                                            2017-12-29 12:20:00  0.000074
#                                            2017-12-29 12:20:00       NaN
#
#                                                                  ret7min  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
# ...                                                                  ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  0.000274
#                                            2017-12-29 12:20:00 -0.000046
#                                            2017-12-29 12:20:00  0.000680
#                                            2017-12-29 12:20:00  0.000293
#                                            2017-12-29 12:20:00  0.000150
#
#                                                                  ret8min  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
# ...                                                                  ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  0.000154
#                                            2017-12-29 12:20:00 -0.001047
#                                            2017-12-29 12:20:00  0.000888
#                                            2017-12-29 12:20:00  0.000147
#                                            2017-12-29 12:20:00 -0.000472
#
#                                                                  ret9min  ...  \
# per_month_interval                         date_time                      ...
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00       NaN  ...
#                                            2015-01-02 09:30:00       NaN  ...
#                                            2015-01-02 09:30:00       NaN  ...
#                                            2015-01-02 09:30:00       NaN  ...
#                                            2015-01-02 09:30:00       NaN  ...
# ...                                                                  ...  ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  0.000405  ...
#                                            2017-12-29 12:20:00 -0.000547  ...
#                                            2017-12-29 12:20:00  0.000915  ...
#                                            2017-12-29 12:20:00 -0.000294  ...
#                                            2017-12-29 12:20:00 -0.000301  ...
#
#                                                                    rdown  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00  0.088409
#                                            2015-01-02 09:30:00  0.943070
#                                            2015-01-02 09:30:00  0.004525
#                                            2015-01-02 09:30:00  0.008880
#                                            2015-01-02 09:30:00  0.871362
# ...                                                                  ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  0.180730
#                                            2017-12-29 12:20:00  0.000000
#                                            2017-12-29 12:20:00  0.162291
#                                            2017-12-29 12:20:00  0.000000
#                                            2017-12-29 12:20:00  1.062092
#
#                                                                      BOP  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00  0.522727
#                                            2015-01-02 09:30:00 -0.625000
#                                            2015-01-02 09:30:00  0.163265
#                                            2015-01-02 09:30:00  0.000000
#                                            2015-01-02 09:30:00  0.857143
# ...                                                                  ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  0.000000
#                                            2017-12-29 12:20:00  0.784017
#                                            2017-12-29 12:20:00 -0.459596
#                                            2017-12-29 12:20:00  0.500000
#                                            2017-12-29 12:20:00 -1.000000
#
#                                                                        CCI  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00         NaN
#                                            2015-01-02 09:30:00         NaN
#                                            2015-01-02 09:30:00         NaN
#                                            2015-01-02 09:30:00         NaN
#                                            2015-01-02 09:30:00         NaN
# ...                                                                    ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  106.003262
#                                            2017-12-29 12:20:00  -73.647793
#                                            2017-12-29 12:20:00  104.116139
#                                            2017-12-29 12:20:00   56.284987
#                                            2017-12-29 12:20:00         NaN
#
#                                                                       MFI  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
# ...                                                                   ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  73.367177
#                                            2017-12-29 12:20:00  71.209698
#                                            2017-12-29 12:20:00  78.603706
#                                            2017-12-29 12:20:00  50.113993
#                                            2017-12-29 12:20:00   3.609527
#
#                                                                  STOCHRSI  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
# ...                                                                   ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  58.931168
#                                            2017-12-29 12:20:00  24.259231
#                                            2017-12-29 12:20:00   0.000000
#                                            2017-12-29 12:20:00  71.537038
#                                            2017-12-29 12:20:00  44.449435
#
#                                                                     slowd  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
# ...                                                                   ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  58.548175
#                                            2017-12-29 12:20:00  19.690598
#                                            2017-12-29 12:20:00  91.051717
#                                            2017-12-29 12:20:00  62.121212
#                                            2017-12-29 12:20:00  25.478525
#
#                                                                     slowk  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
#                                            2015-01-02 09:30:00        NaN
# ...                                                                   ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  72.702457
#                                            2017-12-29 12:20:00  11.871795
#                                            2017-12-29 12:20:00  88.171492
#                                            2017-12-29 12:20:00  60.606061
#                                            2017-12-29 12:20:00  23.657796
#
#                                                                     NATR  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
#                                            2015-01-02 09:30:00       NaN
# ...                                                                  ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00  0.043589
#                                            2017-12-29 12:20:00  0.061051
#                                            2017-12-29 12:20:00  0.057762
#                                            2017-12-29 12:20:00  0.036466
#                                            2017-12-29 12:20:00  0.034838
#
#                                                                 trades_bid_ask  \
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00       -0.302649
#                                            2015-01-02 09:30:00       -0.083074
#                                            2015-01-02 09:30:00        0.000956
#                                            2015-01-02 09:30:00        0.247129
#                                            2015-01-02 09:30:00       -0.003158
# ...                                                                        ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00       -0.352484
#                                            2017-12-29 12:20:00        0.994426
#                                            2017-12-29 12:20:00       -0.467780
#                                            2017-12-29 12:20:00        0.130435
#                                            2017-12-29 12:20:00       -0.174837
#
#                                                                 stock_id
# per_month_interval                         date_time
# [2015-01-01 00:00:00, 2015-02-01 00:00:00) 2015-01-02 09:30:00         0
#                                            2015-01-02 09:30:00         1
#                                            2015-01-02 09:30:00         2
#                                            2015-01-02 09:30:00         3
#                                            2015-01-02 09:30:00         4
# ...                                                                  ...
# [2017-12-01 00:00:00, 2018-01-01 00:00:00) 2017-12-29 12:20:00       134
#                                            2017-12-29 12:20:00       136
#                                            2017-12-29 12:20:00       138
#                                            2017-12-29 12:20:00       139
#                                            2017-12-29 12:20:00       140
#
# [13452358 rows x 24 columns]

# %%
# np.unique(data_by_date_interval.index.get_level_values('per_month_interval')

# %%
# for month, days in data_by_date_interval.groupby(level='per_month_interval', sort=False):
#     print(f"{month=} {type(month)=}\n{len(days)=} {type(days)=}")
#     days.info()
#     # print(f"{days.index.levels=}\n")

# %%
import dask
import dask.dataframe as dd

# So dask has Clusters and allocates processes and threads.
# The i5 has 10 cores, 6 have HyperThreading (2 threads per faster core) and 4 are slower and single threaded.
# A concurrency issue that we frequently run into with Python is the GIL.  So even when it looks parallelizable that may not really happen.

# %%
# @dask.delayed
def month_to_ddf(minutes):
    # return dd.from_pandas(minutes, npartitions=1, sort=False)
    return minutes

months_of_ddf_minutes = []
for month, df in data_by_date_interval.groupby(level='per_month_interval', sort=False):
    minutes = df.reset_index('per_month_interval', drop=True) 
    # print(f"{month=} {type(month)=}\n{len(minutes)=} {type(minutes)=} {type(minutes.index)=}")
    # minutes.info()
    # partitions.append(dask.delayed(dd.from_pandas(minutes, name=month.left.date().strftime("%Y-%m"), npartitions=1, sort=False)))
    # dask.dataframe.from_pandas is replaced by dask.expr.from_pandas which does not support the name arg.
    months_of_ddf_minutes.append(month_to_ddf(minutes.copy()))

# months_of_ddf_minutes

# %%
months_of_ddf_minutes

# %% [markdown]
# Show train/validation periods:

# %% [markdown]
# ### Train model

# %%
label = sorted(data.filter(like='fwd').columns)
features = data.columns.difference(label).tolist()
label = label[0]
label, features
# Out:
# ('fwdwin',
#  ['BOP',
#   'CCI',
#   'MFI',
#   'NATR',
#   'STOCHRSI',
#   'minute',
#   'rdown',
#   'ret10min',
#   'ret1min',
#   'ret2min',
#   'ret3min',
#   'ret4min',
#   'ret5min',
#   'ret6min',
#   'ret7min',
#   'ret8min',
#   'ret9min',
#   'retwin',
#   'rup',
#   'slowd',
#   'slowk',
#   'stock_id',
#   'trades_bid_ask'])

# %%
params = dict(objective='regression',
              metric=['rmse'],
              device='cpu',
              max_bin=63,
              gpu_use_dp=False,
              num_leaves=16,
              min_data_in_leaf=500,
              feature_fraction=.8,
              verbose=-1)

# %%
params = dict(objective='quantile',
              metric=['quantile', 'rmse'],
              device='gpu',
              max_depth=4,
              num_leaves=16,
              # learning_rate=0.1,
              # n_estimators=100,
              boosting_type='gbdt',
              max_bin=63,
              gpu_use_dp=False,
              min_data_in_leaf=500,
              feature_fraction=.8,
              verbose=-1)

# %%
params = dict(objective='regression',
              metric=['rmse'],
              device='gpu',
              max_bin=63,
              gpu_use_dp=False,
              num_leaves=16,
              min_data_in_leaf=500,
              feature_fraction=.8,
              verbose=-1)

# %%
# cv = get_cv(n_splits=23) # we have enough data for 23 different test periods

# %%
def train_test_folds(months_of_ddf_minutes, train_k, test_k, increment=1):
    while len(months_of_ddf_minutes) >= train_k + test_k:
        train_dfs = months_of_ddf_minutes[:train_k]
        test_dfs = months_of_ddf_minutes[train_k:train_k+test_k]
        yield train_dfs, test_dfs
        months_of_ddf_minutes = months_of_ddf_minutes[increment:]

for fold, (train_idx, test_idx) in enumerate(train_test_folds(range(1,36), train_k=12, test_k=1)):
    print(f"{fold=} {len(train_idx)=} {len(test_idx)=}")
# Out:
# fold=0 len(train_idx)=12 len(test_idx)=1
# fold=1 len(train_idx)=12 len(test_idx)=1
# fold=2 len(train_idx)=12 len(test_idx)=1
# fold=3 len(train_idx)=12 len(test_idx)=1
# fold=4 len(train_idx)=12 len(test_idx)=1
# fold=5 len(train_idx)=12 len(test_idx)=1
# fold=6 len(train_idx)=12 len(test_idx)=1
# fold=7 len(train_idx)=12 len(test_idx)=1
# fold=8 len(train_idx)=12 len(test_idx)=1
# fold=9 len(train_idx)=12 len(test_idx)=1
# fold=10 len(train_idx)=12 len(test_idx)=1
# fold=11 len(train_idx)=12 len(test_idx)=1
# fold=12 len(train_idx)=12 len(test_idx)=1
# fold=13 len(train_idx)=12 len(test_idx)=1
# fold=14 len(train_idx)=12 len(test_idx)=1
# fold=15 len(train_idx)=12 len(test_idx)=1
# fold=16 len(train_idx)=12 len(test_idx)=1
# fold=17 len(train_idx)=12 len(test_idx)=1
# fold=18 len(train_idx)=12 len(test_idx)=1
# fold=19 len(train_idx)=12 len(test_idx)=1
# fold=20 len(train_idx)=12 len(test_idx)=1
# fold=21 len(train_idx)=12 len(test_idx)=1
# fold=22 len(train_idx)=12 len(test_idx)=1

# %%
def get_scores(result):
    # print(result['training'].keys())
    # print(result['training'])
    return pd.DataFrame({'train': result['training']['ic'],
                         'valid': result['valid_1']['ic']})

# %% [markdown]
# The following model-training loop will take more than 10 hours to run and also consumes substantial memory. If you run into resource constraints, you can modify the code, e.g., by:
# 1. Only loading data required for one iteration.
# 2. Shortening the training period to require less than one year.
#
# You can also speed up the process by using fewer `n_splits`, which implies longer test periods.

# %%
# @dask.delayed
def train(fold, params, train_dfs, test_dfs, model_path, result_store, num_boost_round=250, stopping_rounds=50):
    start = time()

    # create lgb train set
    # train_set = data.iloc[train_idx, :]
    train_set=pd.concat(train_dfs)
    lgb_train = lgb.Dataset(data=train_set.drop(label, axis=1),
                            label=train_set[label],
                            categorical_feature=categoricals)
    
    # create lgb test set
    # test_set = data.iloc[test_idx, :]
    test_set=pd.concat(test_dfs)
    lgb_test = lgb.Dataset(data=test_set.drop(label, axis=1),
                           label=test_set[label],
                           categorical_feature=categoricals, 
                           reference=lgb_train)

    # train model
    evals_result = {}
    model = lgb.train(params=params,
                      train_set=lgb_train,
                      valid_sets=[lgb_train, lgb_test],
                      feval=ic_lgbm,
                      num_boost_round=num_boost_round,
                      # callbacks=[lgb.record_evaluation(evals_result)])
                      callbacks=[lgb.early_stopping(stopping_rounds=stopping_rounds), lgb.record_evaluation(evals_result)])
    model.save_model((model_path / f'{fold:02}.txt').as_posix())
    
    # get train/valid ic scores
    scores = get_scores(evals_result)
    scores.to_hdf(result_store, f'ic/{fold:02}')
    
    # get feature importance
    fi = get_fi(model)
    fi.to_hdf(result_store, f'fi/{fold:02}')
    
    # generate validation predictions
    X_test = test_set.loc[:, model.feature_name()]
    y_test = test_set.loc[:, [label]]
    y_test['pred'] = model.predict(X_test)
    y_test['stock_id'] = test_set.loc[:, 'stock_id']
    y_test['ticker'] = y_test['stock_id'].apply(lambda id: ticker_to_id[id])
    y_test.to_hdf(result_store, f'predictions/{fold:02}')
    
    # compute average IC per minute
    by_minute = y_test.groupby(test_set.index.get_level_values('date_time'))
    daily_ic = by_minute.apply(lambda x: spearmanr(x.pred, x[label])).mean()
    status = f'\nFold: {fold:02} | {format_time(time()-start)} | IC per minute: {daily_ic:.2%}\n'
    print(status)
    return status

# %%
folds = [train(fold=fold, params=params, train_dfs=train_dfs, test_dfs=test_dfs, model_path=model_path, result_store=result_store) for fold, (train_dfs, test_dfs) in enumerate(train_test_folds(months_of_ddf_minutes, train_k=12, test_k=1))]
# status = dask.compute(folds)
folds
# Out:
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's rmse: 0.00314517	training's ic: 0.124918	valid_1's rmse: 0.00461418	valid_1's ic: 0.0459213
#
# Fold: 00 | 00:00:19 | IC per minute: 2.16%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's rmse: 0.00326036	training's ic: 0.136086	valid_1's rmse: 0.00490918	valid_1's ic: 0.0561642
#
# Fold: 01 | 00:00:21 | IC per minute: 5.52%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [13]	training's rmse: 0.0034431	training's ic: 0.138492	valid_1's rmse: 0.00339812	valid_1's ic: 0.0542382
#
# Fold: 02 | 00:00:22 | IC per minute: 4.59%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [1]	training's rmse: 0.0035225	training's ic: 0.11183	valid_1's rmse: 0.00372935	valid_1's ic: 0.0169349
#
# Fold: 03 | 00:00:20 | IC per minute: 3.38%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [9]	training's rmse: 0.00358457	training's ic: 0.13131	valid_1's rmse: 0.00320195	valid_1's ic: 0.0679526
#
# Fold: 04 | 00:00:21 | IC per minute: 5.13%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's rmse: 0.00362922	training's ic: 0.125205	valid_1's rmse: 0.00303917	valid_1's ic: 0.0623872
#
# Fold: 05 | 00:00:21 | IC per minute: 4.55%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [6]	training's rmse: 0.00367858	training's ic: 0.125398	valid_1's rmse: 0.00268479	valid_1's ic: 0.0536564
#
# Fold: 06 | 00:00:20 | IC per minute: 7.21%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's rmse: 0.00369038	training's ic: 0.107929	valid_1's rmse: 0.00242847	valid_1's ic: 0.0640654
#
# Fold: 07 | 00:00:22 | IC per minute: 3.89%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [11]	training's rmse: 0.00351794	training's ic: 0.0896226	valid_1's rmse: 0.0025769	valid_1's ic: 0.0903922
#
# Fold: 08 | 00:00:21 | IC per minute: 4.98%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [78]	training's rmse: 0.00344492	training's ic: 0.128856	valid_1's rmse: 0.00262564	valid_1's ic: 0.0727929
#
# Fold: 09 | 00:00:29 | IC per minute: 4.22%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [128]	training's rmse: 0.00334547	training's ic: 0.146728	valid_1's rmse: 0.00341083	valid_1's ic: 0.0778191
#
# Fold: 10 | 00:00:35 | IC per minute: 5.44%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's rmse: 0.00337329	training's ic: 0.0824514	valid_1's rmse: 0.00281772	valid_1's ic: 0.0731212
#
# Fold: 11 | 00:00:21 | IC per minute: 3.05%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's rmse: 0.00335285	training's ic: 0.083197	valid_1's rmse: 0.00276668	valid_1's ic: 0.0617401
#
# Fold: 12 | 00:00:20 | IC per minute: 5.04%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [30]	training's rmse: 0.00317943	training's ic: 0.118937	valid_1's rmse: 0.00246816	valid_1's ic: 0.0588051
#
# Fold: 13 | 00:00:22 | IC per minute: 4.86%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's rmse: 0.00296292	training's ic: 0.08833	valid_1's rmse: 0.002202	valid_1's ic: 0.0754104
#
# Fold: 14 | 00:00:22 | IC per minute: 4.25%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's rmse: 0.00286152	training's ic: 0.0877385	valid_1's rmse: 0.0022246	valid_1's ic: 0.0615422
#
# Fold: 15 | 00:00:19 | IC per minute: 3.02%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [86]	training's rmse: 0.00271259	training's ic: 0.133467	valid_1's rmse: 0.00242207	valid_1's ic: 0.0674274
#
# Fold: 16 | 00:00:31 | IC per minute: 3.80%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's rmse: 0.00265947	training's ic: 0.0877423	valid_1's rmse: 0.002762	valid_1's ic: 0.0236966
#
# Fold: 17 | 00:00:21 | IC per minute: 4.06%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [2]	training's rmse: 0.00263463	training's ic: 0.0821266	valid_1's rmse: 0.00268991	valid_1's ic: 0.0248157
#
# Fold: 18 | 00:00:20 | IC per minute: 3.01%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [3]	training's rmse: 0.00263406	training's ic: 0.0790078	valid_1's rmse: 0.00258591	valid_1's ic: 0.011543
#
# Fold: 19 | 00:00:22 | IC per minute: 3.86%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [4]	training's rmse: 0.00264767	training's ic: 0.0722484	valid_1's rmse: 0.0025053	valid_1's ic: 0.0498376
#
# Fold: 20 | 00:00:20 | IC per minute: 4.29%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [17]	training's rmse: 0.00263675	training's ic: 0.0905806	valid_1's rmse: 0.00268154	valid_1's ic: 0.0449283
#
# Fold: 21 | 00:00:23 | IC per minute: 3.65%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [24]	training's rmse: 0.00264034	training's ic: 0.0930365	valid_1's rmse: 0.00310462	valid_1's ic: 0.0539131
#
# Fold: 22 | 00:00:23 | IC per minute: 4.85%
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [37]	training's rmse: 0.00260697	training's ic: 0.0947497	valid_1's rmse: 0.00297123	valid_1's ic: 0.0634851
#
# Fold: 23 | 00:00:24 | IC per minute: 5.69%
# ['\nFold: 00 | 00:00:19 | IC per minute: 2.16%\n',
#  '\nFold: 01 | 00:00:21 | IC per minute: 5.52%\n',
#  '\nFold: 02 | 00:00:22 | IC per minute: 4.59%\n',
#  '\nFold: 03 | 00:00:20 | IC per minute: 3.38%\n',
#  '\nFold: 04 | 00:00:21 | IC per minute: 5.13%\n',
#  '\nFold: 05 | 00:00:21 | IC per minute: 4.55%\n',
#  '\nFold: 06 | 00:00:20 | IC per minute: 7.21%\n',
#  '\nFold: 07 | 00:00:22 | IC per minute: 3.89%\n',
#  '\nFold: 08 | 00:00:21 | IC per minute: 4.98%\n',
#  '\nFold: 09 | 00:00:29 | IC per minute: 4.22%\n',
#  '\nFold: 10 | 00:00:35 | IC per minute: 5.44%\n',
#  '\nFold: 11 | 00:00:21 | IC per minute: 3.05%\n',
#  '\nFold: 12 | 00:00:20 | IC per minute: 5.04%\n',
#  '\nFold: 13 | 00:00:22 | IC per minute: 4.86%\n',
#  '\nFold: 14 | 00:00:22 | IC per minute: 4.25%\n',
#  '\nFold: 15 | 00:00:19 | IC per minute: 3.02%\n',
#  '\nFold: 16 | 00:00:31 | IC per minute: 3.80%\n',
#  '\nFold: 17 | 00:00:21 | IC per minute: 4.06%\n',
#  '\nFold: 18 | 00:00:20 | IC per minute: 3.01%\n',
#  '\nFold: 19 | 00:00:22 | IC per minute: 3.86%\n',
#  '\nFold: 20 | 00:00:20 | IC per minute: 4.29%\n',
#  '\nFold: 21 | 00:00:23 | IC per minute: 3.65%\n',
#  '\nFold: 22 | 00:00:23 | IC per minute: 4.85%\n',
#  '\nFold: 23 | 00:00:24 | IC per minute: 5.69%\n']

# %% [markdown]
# ## Signal Evaluation

# %%
with pd.HDFStore(result_store) as store:
    print(f"{type(store)=}")
    print(f"{store.keys()=}")
    pred_keys = [k[1:] for k in store.keys() if k[1:].startswith('pred')]
    cv_predictions = pd.concat([store[k] for k in pred_keys]).sort_index()
# Out:
# type(store)=<class 'pandas.io.pytables.HDFStore'>
# store.keys()=['/predictions/00', '/predictions/01', '/predictions/02', '/predictions/03', '/predictions/04', '/predictions/05', '/predictions/06', '/predictions/07', '/predictions/08', '/predictions/09', '/predictions/10', '/predictions/11', '/predictions/12', '/predictions/13', '/predictions/14', '/predictions/15', '/predictions/16', '/predictions/17', '/predictions/18', '/predictions/19', '/predictions/20', '/predictions/21', '/predictions/22', '/predictions/23', '/ic/00', '/ic/01', '/ic/02', '/ic/03', '/ic/04', '/ic/05', '/ic/06', '/ic/07', '/ic/08', '/ic/09', '/ic/10', '/ic/11', '/ic/12', '/ic/13', '/ic/14', '/ic/15', '/ic/16', '/ic/17', '/ic/18', '/ic/19', '/ic/20', '/ic/21', '/ic/22', '/ic/23', '/fi/00', '/fi/01', '/fi/02', '/fi/03', '/fi/04', '/fi/05', '/fi/06', '/fi/07', '/fi/08', '/fi/09', '/fi/10', '/fi/11', '/fi/12', '/fi/13', '/fi/14', '/fi/15', '/fi/16', '/fi/17', '/fi/18', '/fi/19', '/fi/20', '/fi/21', '/fi/22', '/fi/23']

# %%
cv_predictions.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8936824 entries, 2016-01-04 09:30:00 to 2017-12-29 12:20:00
# Data columns (total 4 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   fwdwin    8936824 non-null  float64
#  1   pred      8936824 non-null  float64
#  2   stock_id  8936824 non-null  int64
#  3   ticker    8936824 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 340.9+ MB

# %%
time_stamp = cv_predictions.index.get_level_values('date_time')
dates = sorted(np.unique(time_stamp.date))

# %% [markdown]
# We have out-of-sample predictions for 484 days from February 2016 through December 2017:

# %%
print(f'# Days: {len(dates)} | First: {dates[0]} | Last: {dates[-1]}')
# Out:
# # Days: 503 | First: 2016-01-04 | Last: 2017-12-29

# %% [markdown]
# We only use minutes with at least 100 predictions:

# %%
n = cv_predictions.groupby('date_time').size()

# %% [markdown]
# There are ~700 periods, equivalent to a bit over a single trading day (0.67% of all periods in the sample), with fewer than 100 predictions over the 23 test months:

# %%
n
# Out:
# date_time
# 2016-01-04 09:30:00    105
# 2016-01-04 09:31:00    106
# 2016-01-04 09:32:00    106
# 2016-01-04 09:33:00    105
# 2016-01-04 09:34:00    105
#                       ...
# 2017-12-29 12:16:00    102
# 2017-12-29 12:17:00    100
# 2017-12-29 12:18:00    101
# 2017-12-29 12:19:00    102
# 2017-12-29 12:20:00     98
# Length: 86013, dtype: int64

# %%
incomplete_minutes = n[n<100].index
incomplete_minutes
# Out:
# DatetimeIndex(['2016-01-25 10:01:00', '2016-01-27 12:07:00',
#                '2016-01-27 12:16:00', '2016-02-05 09:31:00',
#                '2016-02-23 11:58:00', '2016-02-23 12:07:00',
#                '2016-03-03 12:02:00', '2016-03-04 12:17:00',
#                '2016-03-07 12:13:00', '2016-03-11 12:07:00',
#                ...
#                '2017-12-29 11:55:00', '2017-12-29 12:01:00',
#                '2017-12-29 12:03:00', '2017-12-29 12:04:00',
#                '2017-12-29 12:05:00', '2017-12-29 12:10:00',
#                '2017-12-29 12:11:00', '2017-12-29 12:13:00',
#                '2017-12-29 12:14:00', '2017-12-29 12:20:00'],
#               dtype='datetime64[ns]', name='date_time', length=1412, freq=None)

# %%
print(f'{len(incomplete_minutes)} ({len(incomplete_minutes)/len(n):.2%})')
# Out:
# 1412 (1.64%)

# %%
cv_predictions = cv_predictions[~time_stamp.isin(incomplete_minutes)]
time_stamp = cv_predictions.index.get_level_values('date_time')

# %%
cv_predictions.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8798036 entries, 2016-01-04 09:30:00 to 2017-12-29 12:19:00
# Data columns (total 4 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   fwdwin    8798036 non-null  float64
#  1   pred      8798036 non-null  float64
#  2   stock_id  8798036 non-null  int64
#  3   ticker    8798036 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 335.6+ MB

# %% [markdown]
# ### Information Coefficient

# %% [markdown]
# #### Across all periods

# %%
ic = spearmanr(cv_predictions.fwdwin, cv_predictions.pred)
ic
# Out:
# 0.05408188001926433

# %% [markdown]
# #### By minute

# %% [markdown]
# We are making new predictions every minute, so it makes sense to look at the average performance across all short-term forecasts:

# %%
minutes = cv_predictions.index.get_level_values('date_time')
by_minute = cv_predictions.groupby(minutes)

# %%
ic_by_minute = by_minute.apply(lambda x: spearmanr(x.pred, x.fwdwin))

minute_ic_mean = ic_by_minute.mean()
minute_ic_median = ic_by_minute.median()

print(f'\nAll periods: {ic:6.2%} | By Minute: {minute_ic_mean: 6.2%} (Median: {minute_ic_median: 6.2%})')
# Out:
# All periods:  5.41% | By Minute:  4.34% (Median:  4.66%)

# %%
# from scipy import stats as sp_stats

# ic_by_minute = by_minute.apply(lambda x: sp_stats.spearmanr(x.pred, x.fwdwin)[0])
# minute_ic_mean = ic_by_minute.mean()
# minute_ic_median = ic_by_minute.median()

# print(f'\nAll periods: {ic:6.2%} | By Minute: {minute_ic_mean: 6.2%} (Median: {minute_ic_median: 6.2%})')

# %% [markdown]
# Plotted as a five-day rolling average, we see that the IC was mostly below the out-of-sample period mean, and increased during the last quarter of 2017 (as reflected in the validation results we observed while training the model).
#
# JPW: The periods of low IC correspond to the low diversity of values we filter out for quantiles.  Good to have a filter but unfortunate that these periods can be several months long.

# %%
ax = ic_by_minute.rolling(5*650).mean().plot(figsize=(14, 5), title='IC (5-day MA)', rot=0)
ax.axhline(minute_ic_mean, ls='--', lw=1, c='k')
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
ax.set_ylabel('Information Coefficient')
ax.set_xlabel('')
sns.despine()
plt.tight_layout()

# %% [markdown]
# ### Vectorized backtest of a naive strategey: financial performance by signal quantile

# %% [markdown]
# Alphalens does not work with minute-data, so we need to compute our own signal performance measures.

# %% [markdown]
# Unfortunately, Zipline's Pipeline also doesn't work for minute-data and Backtrader takes a very long time with such a large dataset. Hence, instead of an event-driven backtest of entry/exit rules as in previous examples, we can only create a rough sketch of the financial performance of a naive trading strategy driven by the model's predictions using vectorized backtesting (see Chapter 8 on the [ML4T workflow](../08_ml4t_workflow'). As we will see below, this does not produce particularly helpful results.

# %% [markdown]
# This naive strategy invests in equal-weighted portfolios of the stocks in each decile under the following assumptions (mentioned at the beginning of this notebook:
# 1. Based on the predictions using inputs from the current and previous bars, we can enter positions at the first trade price in the following minute bar
# 2. We exit all positions at the last price in that following minute bar
# 3. There are no trading cost or market impact (slippage) of our trades (but we can check how sensitive the results would be).

# %% [markdown]
# #### Average returns by minute bar and signal quantile

# %% [markdown]
# To this end, we compute the quintiles and deciles of the model's `fwd1min` predictions for each minute:

# %%
# To make quantiles need enough different pred values in order to bin them.

# %%
nv = cv_predictions["pred"].groupby('date_time').nunique()
nv
# Out:
# date_time
# 2016-01-04 09:30:00    28
# 2016-01-04 09:31:00    31
# 2016-01-04 09:32:00    27
# 2016-01-04 09:33:00    20
# 2016-01-04 09:34:00    18
#                        ..
# 2017-12-29 12:15:00    93
# 2017-12-29 12:16:00    92
# 2017-12-29 12:17:00    89
# 2017-12-29 12:18:00    91
# 2017-12-29 12:19:00    91
# Name: pred, Length: 84601, dtype: int64

# %%
nv.info(show_counts=True)
# Out:
# <class 'pandas.core.series.Series'>
# DatetimeIndex: 84601 entries, 2016-01-04 09:30:00 to 2017-12-29 12:19:00
# Series name: pred
# Non-Null Count  Dtype
# --------------  -----
# 84601 non-null  int64
# dtypes: int64(1)
# memory usage: 1.3 MB

# %%
# We don't use minutes where there are not at least 90 different (90% of the tickers) predictions. 
# When the number of different predictions is low then confidence is low.  This appears to usually be during falling markets (but that hasn't been fully confirmed).

# %%
cvn_predictions = cv_predictions[time_stamp.isin(nv[nv > 90].index)]
cvn_predictions.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2031832 entries, 2016-02-08 09:36:00 to 2017-12-29 12:19:00
# Data columns (total 4 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   fwdwin    2031832 non-null  float64
#  1   pred      2031832 non-null  float64
#  2   stock_id  2031832 non-null  int64
#  3   ticker    2031832 non-null  object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 77.5+ MB

# %%
# incomplete_minutesv = nv[nv <= 90].index
# # incomplete_minutesv = nv <= 90
# incomplete_minutesv
cvn_predictions.index
# Out:
# DatetimeIndex(['2016-02-08 09:36:00', '2016-02-08 09:36:00',
#                '2016-02-08 09:36:00', '2016-02-08 09:36:00',
#                '2016-02-08 09:36:00', '2016-02-08 09:36:00',
#                '2016-02-08 09:36:00', '2016-02-08 09:36:00',
#                '2016-02-08 09:36:00', '2016-02-08 09:36:00',
#                ...
#                '2017-12-29 12:19:00', '2017-12-29 12:19:00',
#                '2017-12-29 12:19:00', '2017-12-29 12:19:00',
#                '2017-12-29 12:19:00', '2017-12-29 12:19:00',
#                '2017-12-29 12:19:00', '2017-12-29 12:19:00',
#                '2017-12-29 12:19:00', '2017-12-29 12:19:00'],
#               dtype='datetime64[ns]', name='date_time', length=2031832, freq=None)

# %%
time_values = (cvn_predictions.index.hour * 60) + cvn_predictions.index.minute

# Plot the distribution
plt.figure(figsize=(10, 6))
plt.hist(time_values, bins=24, edgecolor='k', alpha=0.7)
plt.xlabel('Time of Day')
plt.ylabel('Frequency')
plt.title('Distribution of Time Values')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
cvn_predictions.index.min(), cvn_predictions.index.max()
# Out:
# (Timestamp('2016-02-08 09:36:00'), Timestamp('2017-12-29 12:19:00'))

# %%
# Plot the distribution
plt.figure(figsize=(10, 6))
plt.hist(cvn_predictions.index.day_of_week, bins=24, edgecolor='k', alpha=0.7)
plt.xlabel('Time of Day')
plt.ylabel('Frequency')
plt.title('Distribution of Time Values')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
print(f'{len(cvn_predictions.index)} ({len(cvn_predictions.index)/len(cv_predictions.index):.2%})')
# Out:
# 2031832 (23.09%)

# %%
cvn_predictions
# Out:
#                        fwdwin      pred  stock_id ticker
# date_time
# 2016-02-08 09:36:00  0.009608  0.004710         0    AAL
# 2016-02-08 09:36:00 -0.006757  0.000987         1   AAPL
# 2016-02-08 09:36:00 -0.010097  0.004043         2   ADBE
# 2016-02-08 09:36:00 -0.005468  0.000415         3    ADI
# 2016-02-08 09:36:00  0.003629  0.000778         4    ADP
# ...                       ...       ...       ...    ...
# 2017-12-29 12:19:00 -0.000146  0.000200       135   WDAY
# 2017-12-29 12:19:00 -0.000501  0.000209       136    WDC
# 2017-12-29 12:19:00 -0.001365  0.000219       138   WYNN
# 2017-12-29 12:19:00 -0.001102  0.000159       139   XLNX
# 2017-12-29 12:19:00  0.000301  0.000222       140   XRAY
#
# [2031832 rows x 4 columns]

# %%
cv_predictions
# Out:
#                        fwdwin      pred  stock_id ticker
# date_time
# 2016-01-04 09:30:00  0.003190  0.000588         0    AAL
# 2016-01-04 09:30:00  0.012738  0.000588         1   AAPL
# 2016-01-04 09:30:00  0.003063  0.000554         2   ADBE
# 2016-01-04 09:30:00  0.007621  0.000519         3    ADI
# 2016-01-04 09:30:00  0.001815  0.000424         4    ADP
# ...                       ...       ...       ...    ...
# 2017-12-29 12:19:00 -0.000146  0.000200       135   WDAY
# 2017-12-29 12:19:00 -0.000501  0.000209       136    WDC
# 2017-12-29 12:19:00 -0.001365  0.000219       138   WYNN
# 2017-12-29 12:19:00 -0.001102  0.000159       139   XLNX
# 2017-12-29 12:19:00  0.000301  0.000222       140   XRAY
#
# [8798036 rows x 4 columns]

# %%
# cv_predictions = cvn_predictions

# %%
cvn_minutes = cvn_predictions.index.get_level_values('date_time')
cvn_by_minute = cvn_predictions.groupby(cvn_minutes, group_keys=False)

# %%
# There shouldn't be any rows with less than 90 different predictions because we filtered them out above.

# %%
nunique_by_minute = cvn_predictions['pred'].groupby(cvn_minutes, group_keys=False).nunique()
nunique_by_minute[nunique_by_minute <= 90]
# Out:
# Series([], Name: pred, dtype: int64)

# %%
labels = list(range(1, 6))
labels
# Out:
# [1, 2, 3, 4, 5]

# %%
labels = list(range(1, 6))
cvn_predictions['quintile'] = cvn_by_minute.apply(lambda x: pd.qcut(x.pred, q=len(labels), precision=np.inf, labels=labels))

# %%
labels = list(range(1, 11))
cvn_predictions['decile'] = cvn_by_minute.apply(lambda x: pd.qcut(x.pred, q=len(labels), precision=np.inf, labels=labels).astype(int))

# %%
percentiles = [0.98, 1]
cvn_predictions['percentile'] = cvn_by_minute.apply(lambda x: pd.qcut(x.pred, q=percentiles, precision=np.inf, labels=percentiles[:-1]))

# %%
cvn_predictions.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2031832 entries, 2016-02-08 09:36:00 to 2017-12-29 12:19:00
# Data columns (total 7 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   fwdwin      2031832 non-null  float64
#  1   pred        2031832 non-null  float64
#  2   stock_id    2031832 non-null  int64
#  3   ticker      2031832 non-null  object
#  4   quintile    2031832 non-null  category
#  5   decile      2031832 non-null  int64
#  6   percentile  58367 non-null    category
# dtypes: category(2), float64(2), int64(2), object(1)
# memory usage: 96.9+ MB

# %%
cvn_predictions
# Out:
#                        fwdwin      pred  stock_id ticker quintile  decile  \
# date_time
# 2016-02-08 09:36:00  0.009608  0.004710         0    AAL        5      10
# 2016-02-08 09:36:00 -0.006757  0.000987         1   AAPL        3       6
# 2016-02-08 09:36:00 -0.010097  0.004043         2   ADBE        5      10
# 2016-02-08 09:36:00 -0.005468  0.000415         3    ADI        1       1
# 2016-02-08 09:36:00  0.003629  0.000778         4    ADP        3       5
# ...                       ...       ...       ...    ...      ...     ...
# 2017-12-29 12:19:00 -0.000146  0.000200       135   WDAY        3       6
# 2017-12-29 12:19:00 -0.000501  0.000209       136    WDC        4       7
# 2017-12-29 12:19:00 -0.001365  0.000219       138   WYNN        4       8
# 2017-12-29 12:19:00 -0.001102  0.000159       139   XLNX        2       3
# 2017-12-29 12:19:00  0.000301  0.000222       140   XRAY        4       8
#
#                     percentile
# date_time
# 2016-02-08 09:36:00        NaN
# 2016-02-08 09:36:00        NaN
# 2016-02-08 09:36:00        NaN
# 2016-02-08 09:36:00        NaN
# 2016-02-08 09:36:00        NaN
# ...                        ...
# 2017-12-29 12:19:00        NaN
# 2017-12-29 12:19:00        NaN
# 2017-12-29 12:19:00        NaN
# 2017-12-29 12:19:00        NaN
# 2017-12-29 12:19:00        NaN
#
# [2031832 rows x 7 columns]

# %% [markdown]
# #### Descriptive statistics of intraday returns by quintile and decile of model predictions

# %% [markdown]
# Next, we compute the average one-minute returns for each quintile / decile and minute.

# %%
def compute_intraday_returns_by_quantile(predictions, quantile='quintile'):
    by_quantile = predictions.reset_index().groupby(['date_time', quantile])
    return by_quantile.fwdwin.mean().unstack(quantile).sort_index()

# %%
intraday_returns = {'quintile': compute_intraday_returns_by_quantile(cvn_predictions),
                    'decile': compute_intraday_returns_by_quantile(cvn_predictions, quantile='decile'),
                    'percentile': compute_intraday_returns_by_quantile(cvn_predictions, quantile='percentile'),
                   }

# %%
def summarize_intraday_returns(returns):
    summary = returns.describe(deciles)
    return pd.concat([summary.iloc[:1].applymap(lambda x: f'{x:,.0f}'),
                      summary.iloc[1:].applymap(lambda x: f'{x:.4%}')])

# %% [markdown]
# The returns per minute, averaged over the 23-months period, increase by quintile/decile and range from -.3 (-.4) to .27 (.37) basis points for the bottom and top quintile (decile), respectively. While this aligns with the finding of a weakly positive rank correlation coefficient, it also suggests that such small gains are unlikely to survive the impact of trading costs.

# %%
summary = summarize_intraday_returns(intraday_returns['quintile'])
summary
# Out:
# quintile         1         2         3         4         5
# count       19,574    19,574    19,574    19,574    19,574
# mean       0.0204%   0.0261%   0.0304%   0.0349%   0.0512%
# std        0.1033%   0.1117%   0.1220%   0.1397%   0.1760%
# min       -1.2049%  -1.1764%  -1.1016%  -1.1469%  -1.2306%
# 10%       -0.0855%  -0.0903%  -0.1035%  -0.1181%  -0.1386%
# 20%       -0.0412%  -0.0441%  -0.0470%  -0.0550%  -0.0673%
# 30%       -0.0158%  -0.0162%  -0.0157%  -0.0189%  -0.0238%
# 40%        0.0038%   0.0060%   0.0084%   0.0082%   0.0133%
# 50%        0.0218%   0.0268%   0.0310%   0.0340%   0.0469%
# 60%        0.0392%   0.0465%   0.0527%   0.0605%   0.0812%
# 70%        0.0589%   0.0694%   0.0783%   0.0902%   0.1177%
# 80%        0.0831%   0.0982%   0.1100%   0.1272%   0.1662%
# 90%        0.1251%   0.1445%   0.1632%   0.1882%   0.2509%
# max        1.3032%   1.2336%   1.0353%   1.3162%   2.0382%

# %%
summary = summarize_intraday_returns(intraday_returns['decile'])
summary
# Out:
# decile        1         2         3         4         5         6         7   \
# count     19,574    19,574    19,574    19,574    19,574    19,574    19,574
# mean     0.0194%   0.0215%   0.0251%   0.0273%   0.0291%   0.0318%   0.0324%
# std      0.1110%   0.1134%   0.1177%   0.1254%   0.1292%   0.1385%   0.1469%
# min     -1.2910%  -1.4893%  -1.8098%  -1.6327%  -1.0282%  -1.2668%  -1.1972%
# 10%     -0.0936%  -0.0971%  -0.1002%  -0.1056%  -0.1120%  -0.1198%  -0.1297%
# 20%     -0.0457%  -0.0497%  -0.0500%  -0.0545%  -0.0549%  -0.0600%  -0.0650%
# 30%     -0.0197%  -0.0202%  -0.0201%  -0.0217%  -0.0211%  -0.0231%  -0.0250%
# 40%      0.0009%   0.0018%   0.0037%   0.0043%   0.0052%   0.0046%   0.0056%
# 50%      0.0204%   0.0224%   0.0258%   0.0268%   0.0299%   0.0306%   0.0326%
# 60%      0.0397%   0.0425%   0.0481%   0.0505%   0.0541%   0.0569%   0.0601%
# 70%      0.0607%   0.0651%   0.0716%   0.0766%   0.0813%   0.0874%   0.0914%
# 80%      0.0868%   0.0936%   0.1015%   0.1091%   0.1154%   0.1235%   0.1321%
# 90%      0.1293%   0.1409%   0.1515%   0.1609%   0.1696%   0.1853%   0.1950%
# max      1.4539%   1.3637%   1.0453%   1.5312%   1.0503%   1.2403%   1.2917%
#
# decile        8         9         10
# count     19,574    19,574    19,574
# mean     0.0373%   0.0417%   0.0598%
# std      0.1604%   0.1772%   0.2156%
# min     -1.1012%  -1.2862%  -1.3910%
# 10%     -0.1378%  -0.1529%  -0.1745%
# 20%     -0.0703%  -0.0771%  -0.0895%
# 30%     -0.0275%  -0.0317%  -0.0345%
# 40%      0.0047%   0.0063%   0.0105%
# 50%      0.0352%   0.0408%   0.0524%
# 60%      0.0660%   0.0744%   0.0936%
# 70%      0.0998%   0.1135%   0.1410%
# 80%      0.1453%   0.1612%   0.2039%
# 90%      0.2162%   0.2379%   0.3074%
# max      1.5012%   2.5110%   1.7416%

# %%
summary = summarize_intraday_returns(intraday_returns['percentile'])
summary
# Out:
# percentile      0.98
# count         19,574
# mean         0.0752%
# std          0.3641%
# min         -2.1898%
# 10%         -0.3244%
# 20%         -0.1692%
# 30%         -0.0769%
# 40%         -0.0031%
# 50%          0.0667%
# 60%          0.1361%
# 70%          0.2146%
# 80%          0.3138%
# 90%          0.4892%
# max          4.9673%

# %%
intraday_returns['percentile'].max()
# Out:
# percentile
# 0.98    0.049673
# dtype: float64

# %%
dfir = intraday_returns['percentile']
dfir
# Out:
# percentile               0.98
# date_time
# 2016-02-08 09:36:00  0.005448
# 2016-02-08 09:38:00 -0.003441
# 2016-02-08 09:39:00 -0.001947
# 2016-02-11 09:39:00 -0.002033
# 2016-02-12 09:38:00 -0.012693
# ...                       ...
# 2017-12-29 12:12:00  0.000653
# 2017-12-29 12:15:00  0.001445
# 2017-12-29 12:16:00  0.000984
# 2017-12-29 12:18:00 -0.000086
# 2017-12-29 12:19:00  0.000404
#
# [19574 rows x 1 columns]

# %%
dfir.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19574 entries, 2016-02-08 09:36:00 to 2017-12-29 12:19:00
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0.98    19574 non-null  float64
# dtypes: float64(1)
# memory usage: 305.8 KB

# %%
dfir.columns.categories
# Out:
# Index([0.98], dtype='float64')

# %% [markdown]
# #### Cumulative Performance by Quantile

# %% [markdown]
# To simulate the performance of our naive strategy that trades all available stocks every minute, we simply assume that we can reinvest (including potential gains/losses) every minute. To check for the sensitivity with respect for trading cost, we can assume they are a constant number (fraction) of basis points, and subtract this number from the minute-bar returns.

# %%
def plot_cumulative_performance(returns, quantile='quintile', trading_costs_bp=0):
    """Plot average return by quantile (in bp) as well as cumulative return, 
        both net of trading costs (provided as basis points; 1bp = 0.01%) 
    """

    fig, axes = plt.subplots(figsize=(14, 4), ncols=2)

    sns.barplot(y='fwdwin', x=quantile,
                data=returns[quantile].mul(10000).sub(trading_costs_bp).stack().to_frame(
                    'fwdwin').reset_index(),
                ax=axes[0])
    axes[0].set_title(f'Avg. 1-min Return by Signal {quantile.capitalize()}')
    axes[0].set_ylabel('Return (bps)')
    axes[0].set_xlabel(quantile.capitalize())

    title = f'Cumulative Return by Signal {quantile.capitalize()}'
    (returns[quantile].sort_index().add(1).sub(trading_costs_bp/10000).cumprod().sub(1)
     .plot(ax=axes[1], title=title))

    axes[1].yaxis.set_major_formatter(
        FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
    axes[1].set_xlabel('')
    axes[1].set_ylabel('Return')
    fig.suptitle(f'Average and Cumulative Performance (Net of Trading Cost: {trading_costs_bp:.2f}bp)')

    sns.despine()
    fig.tight_layout()

# %% [markdown]
# Without trading costs, the compounding of even fairly small gains leads to extremely large cumulative profits for the top quantile. However, these disappear as soon as we allow for minuscule trading costs that reduce the average quantile return close to zero.

# %% [markdown]
# ##### Without trading costs

# %%
plot_cumulative_performance(intraday_returns, 'quintile', trading_costs_bp=0)

# %%
plot_cumulative_performance(intraday_returns, 'decile', trading_costs_bp=0)

# %%
plot_cumulative_performance(intraday_returns, 'percentile', trading_costs_bp=0)

# %% [markdown]
# ##### With extremely low trading costs

# %%
# assuming costs of a fraction of a basis point, close to the average return of the top quantile
plot_cumulative_performance(intraday_returns, 'quintile', trading_costs_bp=.2)

# %%
plot_cumulative_performance(intraday_returns, 'decile', trading_costs_bp=1.2)

# %%
plot_cumulative_performance(intraday_returns, 'percentile', trading_costs_bp=1.2)

# %% [markdown]
# ### Accumulated (Not Compounded) Returns

# %%
def plot_accumulated_performance(returns, quantile='quintile', trading_costs_bp=0):
    """Plot average return by quantile (in bp) as well as cumulative return, 
        both net of trading costs (provided as basis points; 1bp = 0.01%) 
    """

    fig, axes = plt.subplots(figsize=(14, 4), ncols=2)

    sns.barplot(y='fwdwin', x=quantile,
                data=returns[quantile].mul(10000).sub(trading_costs_bp).stack().to_frame(
                    'fwdwin').reset_index(),
                ax=axes[0])
    axes[0].set_title(f'Avg. 1-min Return by Signal {quantile.capitalize()}')
    axes[0].set_ylabel('Return (bps)')
    axes[0].set_xlabel(quantile.capitalize())

    title = f'Cumulative Return by Signal {quantile.capitalize()}'
    (returns[quantile].sort_index().add(1).sub(trading_costs_bp/10000).cumprod().sub(1)
     .plot(ax=axes[1], title=title))

    axes[1].yaxis.set_major_formatter(
        FuncFormatter(lambda y, _: '{:.0%}'.format(y)))
    axes[1].set_xlabel('')
    axes[1].set_ylabel('Return')
    fig.suptitle(f'Average and Cumulative Performance (Net of Trading Cost: {trading_costs_bp:.2f}bp)')

    sns.despine()
    fig.tight_layout()

# %% [markdown]
# ### Feature Importance

# %% [markdown]
# We'll take a quick look at the features that most contributed to improving the IC across the 23 folds:

# %%
with pd.HDFStore(result_store) as store:
    fi_keys = [k[1:] for k in store.keys() if k[1:].startswith('fi')]
    fi = pd.concat([store[k].to_frame(i) for i, k in enumerate(fi_keys, 1)], axis=1)

# %% [markdown]
# The top features from a conventional feature importance perspective are the ticker, followed by NATR, minute of the day, latest 1m return and the CCI:

# %%
fi.mean(1).nsmallest(25).plot.barh(figsize=(12, 8), title='LightGBM Feature Importance (gain)')
sns.despine()
plt.tight_layout();

# %% [markdown]
# Explore with greater accuracy and in more detail how feature values affect predictions using SHAP values as demonstrated in various other notebooks in this Chapter and the appendix!

# %% [markdown]
# ## Conclusion
#
# We have seen that a relatively simple gradient boosting model is able to achieve fairly consistent predictive performance that is significantly better than a random guess even on a very short horizon.
#
# However, the resulting economic gains of our naive strategy of frequently buying/(short-)selling the top/bottome quantiles are too small to overcome the inevitable transaction costs. On the one hand, this demonstrates the challenges of extracting value from a predictive signal. On the other hand, it shows that we need a more sophisticated backtesting platform so that we can even begin to design and evaluate a more sophisticated strategy that requires far fewer trades to exploit the signal in our ML predictions.
#
# In addition, we would also want to work on improving the model by adding more informative feature, e.g. based on the quote/trade info contained in the Algoseek data, or by fine-tuning our model architecture and hyperparameter settings.

# %%
all_cv_predictions = cv_predictions

# %%
cv_predictions = all_cv_predictions
# cv_predictions = all_cv_predictions[0:20000]
minutes = cv_predictions.index.get_level_values('date_time')
by_minute = cv_predictions.groupby(by=minutes, sort=False)

# %%
by_minute.apply(lambda g: g.index.unique())
# Out:
# date_time
# 2016-01-04 09:30:00    DatetimeIndex(['2016-01-04 09:30:00'], dtype='...
# 2016-01-04 09:31:00    DatetimeIndex(['2016-01-04 09:31:00'], dtype='...
# 2016-01-04 09:32:00    DatetimeIndex(['2016-01-04 09:32:00'], dtype='...
# 2016-01-04 09:33:00    DatetimeIndex(['2016-01-04 09:33:00'], dtype='...
# 2016-01-04 09:34:00    DatetimeIndex(['2016-01-04 09:34:00'], dtype='...
#                                              ...
# 2017-12-29 12:15:00    DatetimeIndex(['2017-12-29 12:15:00'], dtype='...
# 2017-12-29 12:16:00    DatetimeIndex(['2017-12-29 12:16:00'], dtype='...
# 2017-12-29 12:17:00    DatetimeIndex(['2017-12-29 12:17:00'], dtype='...
# 2017-12-29 12:18:00    DatetimeIndex(['2017-12-29 12:18:00'], dtype='...
# 2017-12-29 12:19:00    DatetimeIndex(['2017-12-29 12:19:00'], dtype='...
# Length: 84601, dtype: object

# %%
def foo(g):
    return g.index.unique()

by_minute.apply(foo)
# Out:
# date_time
# 2016-01-04 09:30:00    DatetimeIndex(['2016-01-04 09:30:00'], dtype='...
# 2016-01-04 09:31:00    DatetimeIndex(['2016-01-04 09:31:00'], dtype='...
# 2016-01-04 09:32:00    DatetimeIndex(['2016-01-04 09:32:00'], dtype='...
# 2016-01-04 09:33:00    DatetimeIndex(['2016-01-04 09:33:00'], dtype='...
# 2016-01-04 09:34:00    DatetimeIndex(['2016-01-04 09:34:00'], dtype='...
#                                              ...
# 2016-01-05 09:44:00    DatetimeIndex(['2016-01-05 09:44:00'], dtype='...
# 2016-01-05 09:45:00    DatetimeIndex(['2016-01-05 09:45:00'], dtype='...
# 2016-01-05 09:46:00    DatetimeIndex(['2016-01-05 09:46:00'], dtype='...
# 2016-01-05 09:47:00    DatetimeIndex(['2016-01-05 09:47:00'], dtype='...
# 2016-01-05 09:48:00    DatetimeIndex(['2016-01-05 09:48:00'], dtype='...
# Length: 190, dtype: object

# %%
minutes_df = minutes.to_frame()
minutes_df['date'] = minutes.date
minutes_df['time'] = minutes.time
minutes_df
# Out:
#                               date_time        date      time
# date_time
# 2016-01-04 09:30:00 2016-01-04 09:30:00  2016-01-04  09:30:00
# 2016-01-04 09:30:00 2016-01-04 09:30:00  2016-01-04  09:30:00
# 2016-01-04 09:30:00 2016-01-04 09:30:00  2016-01-04  09:30:00
# 2016-01-04 09:30:00 2016-01-04 09:30:00  2016-01-04  09:30:00
# 2016-01-04 09:30:00 2016-01-04 09:30:00  2016-01-04  09:30:00
# ...                                 ...         ...       ...
# 2016-01-05 09:48:00 2016-01-05 09:48:00  2016-01-05  09:48:00
# 2016-01-05 09:48:00 2016-01-05 09:48:00  2016-01-05  09:48:00
# 2016-01-05 09:48:00 2016-01-05 09:48:00  2016-01-05  09:48:00
# 2016-01-05 09:48:00 2016-01-05 09:48:00  2016-01-05  09:48:00
# 2016-01-05 09:48:00 2016-01-05 09:48:00  2016-01-05  09:48:00
#
# [20000 rows x 3 columns]

# %%
end_of_day_time = minutes.time.max()
end_of_day_time
# Out:
# datetime.time(12, 20)

# %%
top_preds = by_minute['pred'].idxmax()
top_preds
# Out:
# date_time
# 2016-01-04 09:30:00   2016-01-04 09:30:00
# 2016-01-04 09:31:00   2016-01-04 09:31:00
# 2016-01-04 09:32:00   2016-01-04 09:32:00
# 2016-01-04 09:33:00   2016-01-04 09:33:00
# 2016-01-04 09:34:00   2016-01-04 09:34:00
#                               ...
# 2016-01-05 09:44:00   2016-01-05 09:44:00
# 2016-01-05 09:45:00   2016-01-05 09:45:00
# 2016-01-05 09:46:00   2016-01-05 09:46:00
# 2016-01-05 09:47:00   2016-01-05 09:47:00
# 2016-01-05 09:48:00   2016-01-05 09:48:00
# Name: pred, Length: 190, dtype: datetime64[ns]

# %%
cv_predictions.loc[top_preds]
# Out:
#                        fwdwin      pred  stock_id ticker
# date_time
# 2016-01-04 09:30:00  0.003190  0.000588         0    AAL
# 2016-01-04 09:30:00  0.012738  0.000588         1   AAPL
# 2016-01-04 09:30:00  0.003063  0.000554         2   ADBE
# 2016-01-04 09:30:00  0.007621  0.000519         3    ADI
# 2016-01-04 09:30:00  0.001815  0.000424         4    ADP
# ...                       ...       ...       ...    ...
# 2016-01-05 09:48:00 -0.003216  0.000353        39   CTXS
# 2016-01-05 09:48:00 -0.010542  0.000371        40  DISCA
# 2016-01-05 09:48:00 -0.010697  0.000371        41  DISCK
# 2016-01-05 09:48:00 -0.005862  0.000353        42   DISH
# 2016-01-05 09:48:00 -0.001989  0.000353        43   DLTR
#
# [20000 rows x 4 columns]

# %%
group_count = 0

def print_group(group):
    global group_count
    # print(f"{group['pred'].nunique()=}")
    if group['pred'].nunique() > 70:
        group_count += 1
        if group_count <= 10:
            # print(f"{group=}")
            # print(f"{group.index=}")
            print(f"{group.index.min()=}")
            print(f"{group.index.unique()=}")
            # print(f"{group['pred'].idxmax()=}")
            # print(f"{type(group)=}")
            group.info()
            print(f"{group['pred'].max()=}")
            # print(f"{group.loc[group['pred'].idxmax()]=}")
            # print(f"{type(group['pred'])=}")
            # print(f"{group['pred']=}")
            print(f"{group['pred'].argmax()=}")
            # print(f"{ticker_to_id[group['pred'].argmax()]=}")
            print(f"{group.iloc[group['pred'].argmax()]=}")
            # print(f"{group.sort(['pred']).last()=}")

by_minute.apply(print_group, include_groups=False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
group_count = 0

def print_group(group):
    global group_count
    group_count += 1
    if group_count <= 10:
        print(f"{group=}")
        top_id = group['pred'].idxmax()
        top_ticker = ticker_to_id[top_id]
        print(f"{top_id=} {top_ticker=} {group.iloc[top_id]

by_minute.apply(print_group)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 13452358 entries, ('AAL', Timestamp('2015-01-02 09:30:00')) to ('YHOO', Timestamp('2017-06-16 12:20:00'))
# Data columns (total 24 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   minute          int64
#  1   ret1min         float64
#  2   ret2min         float64
#  3   ret3min         float64
#  4   ret4min         float64
#  5   ret5min         float64
#  6   ret6min         float64
#  7   ret7min         float64
#  8   ret8min         float64
#  9   ret9min         float64
#  10  ret10min        float64
#  11  retwin          float64
#  12  fwdwin          float64
#  13  rup             float64
#  14  rdown           float64
#  15  BOP             float64
#  16  CCI             float64
#  17  MFI             float64
#  18  STOCHRSI        float64
#  19  slowd           float64
#  20  slowk           float64
#  21  NATR            float64
#  22  trades_bid_ask  float64
#  23  stock_id        int64
# dtypes: float64(22), int64(2)
# memory usage: 2.5+ GB

# %%
def best_stock_prediction(group):
    return group.iloc[group['pred'].argmax()]

best_prediction_per_minute = by_minute.apply(best_stock_prediction)
best_prediction_per_minute
# Out:
#                        fwdwin      pred  stock_id ticker
# date_time
# 2016-01-04 09:30:00  0.006298  0.005026       121   SYMC
# 2016-01-04 09:31:00 -0.004972  0.005026        72     JD
# 2016-01-04 09:32:00  0.000452  0.003997        36   CTRP
# 2016-01-04 09:33:00 -0.010532  0.003278        14   ATVI
# 2016-01-04 09:34:00 -0.007639  0.003278        19   BIDU
# ...                       ...       ...       ...    ...
# 2017-12-29 12:15:00  0.003724  0.000390       114   SIRI
# 2017-12-29 12:16:00 -0.000772  0.000389        89   MELI
# 2017-12-29 12:17:00  0.003724  0.000363       114   SIRI
# 2017-12-29 12:18:00  0.002048  0.000378       114   SIRI
# 2017-12-29 12:19:00  0.002793  0.000377       114   SIRI
#
# [84601 rows x 4 columns]

# %%
workspace_path = Path(os.environ.get("PROJECTS_DIR"), "machine-learning-for-trading")
nasdaq_path = workspace_path / 'data/nasdaq100'
algoseek_path = nasdaq_path / 'algoseek-longer.h5'

# %%
ohlcv_cols = ['first', 'high', 'low', 'last', 'price', 'volume']
data_cols = ohlcv_cols + ['up', 'down', 'rup', 'rdown', 'atask', 'atbid']
# This is in PyPi tables
with pd.HDFStore(algoseek_path) as store:
    algoseek_df = store['min_taq'].loc[:, data_cols].sort_index()
algoseek_df.index.rename(['ticker', 'date_time'], inplace=True)
algoseek_df
# Out:
#                              first   high    low     last     price  volume  \
# ticker date_time
# AAL    2015-01-02 09:30:00  54.230  54.60  54.16  54.4600  54.29077  322952
#        2015-01-02 09:31:00  54.460  54.53  54.03  54.0300  54.25423   41021
#        2015-01-02 09:32:00  54.030  54.38  54.03  54.3300  54.21918   38838
#        2015-01-02 09:33:00  54.350  54.37  54.02  54.0200  54.17345   28495
#        2015-01-02 09:34:00  54.030  54.47  54.03  54.4500  54.25115   33939
# ...                            ...    ...    ...      ...       ...     ...
# YHOO   2017-06-16 12:26:00  52.270  52.28  52.27  52.2800  52.27499   44661
#        2017-06-16 12:27:00  52.280  52.28  52.27  52.2700  52.27085   28929
#        2017-06-16 12:28:00  52.275  52.30  52.27  52.2950  52.28527  101998
#        2017-06-16 12:29:00  52.291  52.30  52.25  52.2500  52.27528   50636
#        2017-06-16 12:30:00  52.245  52.25  52.23  52.2389  52.23807   33697
#
#                                up    down     rup  rdown   atask   atbid
# ticker date_time
# AAL    2015-01-02 09:30:00  38994  212658  103880  28552  121743  219484
#        2015-01-02 09:31:00  21769   26602   11350  24854   13539   35267
#        2015-01-02 09:32:00  23979   18662   26748   9663   34225   15960
#        2015-01-02 09:33:00  14918   20112    7143  14687    6819   17940
#        2015-01-02 09:34:00  13292    7437   29723   3664   30543    9307
# ...                           ...     ...     ...    ...     ...     ...
# YHOO   2017-06-16 12:26:00   6505    5967   20908  26378   24434   26578
#        2017-06-16 12:27:00   5480    6225    5023  30428    5800   32528
#        2017-06-16 12:28:00  31558    9850   77951  42382   74346   39753
#        2017-06-16 12:29:00   6424    5549    9334  48119   15782   43701
#        2017-06-16 12:30:00   4702    4716    8889  24991   11810   27352
#
# [14514933 rows x 12 columns]

# %%
algoseek_df.loc['JD']
# Out:
#                        first     high    low    last     price  volume     up  \
# date_time
# 2015-07-29 09:30:00  32.6600  32.9400  32.60  32.895  32.67687   45887   3152
# 2015-07-29 09:31:00  32.8700  32.9700  32.82  32.905  32.92683   21262  10935
# 2015-07-29 09:32:00  32.9000  33.0000  32.73  32.970  32.90049   61804  16650
# 2015-07-29 09:33:00  32.9600  33.0000  32.75  32.790  32.88637   40882  16335
# 2015-07-29 09:34:00  32.7700  32.9200  32.72  32.910  32.80036   23238   5080
# ...                      ...      ...    ...     ...       ...     ...    ...
# 2017-12-29 12:26:00  41.5900  41.6001  41.59  41.600  41.59864    9102   3420
# 2017-12-29 12:27:00  41.6000  41.6000  41.59  41.600  41.59706    1416    226
# 2017-12-29 12:28:00  41.6000  41.6000  41.59  41.600  41.59911    9544    884
# 2017-12-29 12:29:00  41.5902  41.6100  41.59  41.600  41.59732    6418   4012
# 2017-12-29 12:30:00  41.6000  41.6500  41.60  41.650  41.62706    1700    385
#
#                       down    rup  rdown  atask  atbid
# date_time
# 2015-07-29 09:30:00  35663   4199   7726  11663   3962
# 2015-07-29 09:31:00   8981  13496   7658  17926   9109
# 2015-07-29 09:32:00  12430  25709  22945  24420  31219
# 2015-07-29 09:33:00  22604   6130  26703   8200  38482
# 2015-07-29 09:34:00   6482   9810   8906  11750  10488
# ...                    ...    ...    ...    ...    ...
# 2017-12-29 12:26:00   2447   7036   1386   6500   1766
# 2017-12-29 12:27:00    303    800    213   1001    516
# 2017-12-29 12:28:00    501   7660    852   6329   2201
# 2017-12-29 12:29:00    782   3095   2346   3751   1879
# 2017-12-29 12:30:00      1   1700    200   1460    603
#
# [110772 rows x 12 columns]

# %%
positions = {}

all_trades = []

def open_position(ticker, pred_datetime):
    global algoseek_df
    open_datetime = pred_datetime + pd.Timedelta(minutes=1)
    # position['open_datetime'] = open_datetime
    # position['open_price'] = data.loc[ticker, open_datetime]['price']
    # print(f"{algoseek_df.loc[ticker, open_datetime]=}")
    # print(f"{algoseek_df.loc[ticker, open_datetime]['price']=}")
    return {'ticker': ticker, 'open_datetime':open_datetime, 'open_price':algoseek_df.loc[ticker, open_datetime]['price']}
    
def close_position(position, pred_datetime):
    global algoseek_df
    global all_trades
    close_datetime = pred_datetime + pd.Timedelta(minutes=1)
    position['close_datetime'] = close_datetime
    # print(f"{algoseek_df.loc[position['ticker'], close_datetime]=}")
    position['close_price'] = algoseek_df.loc[position['ticker'], close_datetime]['price']
    position['gain'] = (position['close_price'] - position['open_price']) / position['open_price']
    all_trades.append(position)
    return position

def trading_strategy(group):
    global cv_predictions
    global positions

    c = 70
    k = 10

    trades = []

    # group.info()
    # print(f"{group=}")

    # print(f"{group.index.unique()=}")
    this_datetime = group.index.unique().min()
    # print(f"{this_datetime=}")
    if this_datetime.time() >= end_of_day_time:
        for position in positions.values():
            trades.append(close_position(position, this_datetime))
        positions = {}
        return pd.DataFrame(trades)

    # top_pred = best_stock_prediction(group)
    top_preds = group.sort_values('pred', ascending=False).head(k)
    # top_ticker = top_pred['ticker']
    top_ticker = top_preds.iloc[0]['ticker']
    # print(f"{this_datetime=} {top_ticker=} {positions=}")
    # print(f"{ticker=}")
    # print(f"{group=}")
    # by_ticker = group.set_index('ticker')
    # by_ticker.info()
    # print(f"{top_preds=}")
    top_tickers = top_preds['ticker']
    for ticker, position in positions.copy().items():
        if not ticker in top_tickers:
            # print(f"{by_ticker.loc[ticker]=}")
            # try:
            #     ticker_pred = by_ticker.loc[ticker]
            #     print(f"{ticker_pred=}")
            #     if ticker_pred['pred'] < 0:
            #         trades.append(close_position(position, this_datetime))
            # except KeyError:
            #     print(f"missing {ticker=}")
            #     trades.append(close_position(position, this_datetime))
            trades.append(close_position(position, this_datetime))
            del positions[ticker]

    # print(f"{group['pred'].nunique()=}")
    if (not top_ticker in positions) and (group['pred'].nunique() > c):
        positions[top_ticker] = open_position(top_ticker, this_datetime)
        
    if trades:
        return pd.DataFrame(trades)
    return None

trades = by_minute.apply(trading_strategy)
len(all_trades)
# Out:
# 24598

# %%
pd.DataFrame(all_trades)['gain'].sum()
# Out:
# 0.8841870484812204

# %%
all_trades
# Out:
# [{'ticker': 'TSLA',
#   'open_datetime': Timestamp('2016-02-01 09:37:00'),
#   'open_price': 185.44324,
#   'close_datetime': Timestamp('2016-02-01 09:38:00'),
#   'close_price': 186.1849,
#   'gain': 0.003999390864827404},
#  {'ticker': 'WDC',
#   'open_datetime': Timestamp('2016-02-01 09:42:00'),
#   'open_price': 47.49934,
#   'close_datetime': Timestamp('2016-02-01 09:43:00'),
#   'close_price': 47.49737,
#   'gain': -4.147426048446205e-05},
#  {'ticker': 'PCAR',
#   'open_datetime': Timestamp('2016-02-01 09:47:00'),
#   'open_price': 47.58987,
#   'close_datetime': Timestamp('2016-02-01 09:48:00'),
#   'close_price': 47.70308,
#   'gain': 0.0023788676035467688},
#  {'ticker': 'MNST',
#   'open_datetime': Timestamp('2016-02-01 09:48:00'),
#   'open_price': 136.62678,
#   'close_datetime': Timestamp('2016-02-01 09:49:00'),
#   'close_price': 136.43041,
#   'gain': -0.0014372731319584762},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-01 09:50:00'),
#   'open_price': 92.65965,
#   'close_datetime': Timestamp('2016-02-01 09:51:00'),
#   'close_price': 92.51219,
#   'gain': -0.00159141546509182},
#  {'ticker': 'PCAR',
#   'open_datetime': Timestamp('2016-02-01 09:51:00'),
#   'open_price': 47.57227,
#   'close_datetime': Timestamp('2016-02-01 09:52:00'),
#   'close_price': 47.59404,
#   'gain': 0.0004576195333961678},
#  {'ticker': 'ADP',
#   'open_datetime': Timestamp('2016-02-02 09:31:00'),
#   'open_price': 82.37904,
#   'close_datetime': Timestamp('2016-02-02 09:32:00'),
#   'close_price': 82.56923,
#   'gain': 0.002308718334178223},
#  {'ticker': 'WDC',
#   'open_datetime': Timestamp('2016-02-02 09:38:00'),
#   'open_price': 48.3128,
#   'close_datetime': Timestamp('2016-02-02 09:39:00'),
#   'close_price': 48.05933,
#   'gain': -0.005246435727177892},
#  {'ticker': 'WDC',
#   'open_datetime': Timestamp('2016-02-02 09:39:00'),
#   'open_price': 48.05933,
#   'close_datetime': Timestamp('2016-02-02 09:40:00'),
#   'close_price': 47.82321,
#   'gain': -0.004913093877921304},
#  {'ticker': 'ADP',
#   'open_datetime': Timestamp('2016-02-02 09:40:00'),
#   'open_price': 82.22066,
#   'close_datetime': Timestamp('2016-02-02 09:41:00'),
#   'close_price': 82.13466,
#   'gain': -0.0010459658192964946},
#  {'ticker': 'ADP',
#   'open_datetime': Timestamp('2016-02-02 09:41:00'),
#   'open_price': 82.13466,
#   'close_datetime': Timestamp('2016-02-02 09:42:00'),
#   'close_price': 82.20119,
#   'gain': 0.0008100112668634679},
#  {'ticker': 'ADP',
#   'open_datetime': Timestamp('2016-02-02 09:42:00'),
#   'open_price': 82.20119,
#   'close_datetime': Timestamp('2016-02-02 09:43:00'),
#   'close_price': 82.31493,
#   'gain': 0.0013836782654850503},
#  {'ticker': 'ADP',
#   'open_datetime': Timestamp('2016-02-02 09:43:00'),
#   'open_price': 82.31493,
#   'close_datetime': Timestamp('2016-02-02 09:44:00'),
#   'close_price': 82.25596,
#   'gain': -0.0007163949480367922},
#  {'ticker': 'AVGO',
#   'open_datetime': Timestamp('2016-02-02 09:44:00'),
#   'open_price': 134.1822,
#   'close_datetime': Timestamp('2016-02-02 09:45:00'),
#   'close_price': 133.99329,
#   'gain': -0.0014078618475475348},
#  {'ticker': 'ADP',
#   'open_datetime': Timestamp('2016-02-02 09:45:00'),
#   'open_price': 82.18752,
#   'close_datetime': Timestamp('2016-02-02 09:46:00'),
#   'close_price': 82.08976,
#   'gain': -0.0011894749957172092},
#  {'ticker': 'ADP',
#   'open_datetime': Timestamp('2016-02-02 09:46:00'),
#   'open_price': 82.08976,
#   'close_datetime': Timestamp('2016-02-02 09:47:00'),
#   'close_price': 81.988,
#   'gain': -0.0012396186808196143},
#  {'ticker': 'WDC',
#   'open_datetime': Timestamp('2016-02-02 09:47:00'),
#   'open_price': 47.49764,
#   'close_datetime': Timestamp('2016-02-02 09:48:00'),
#   'close_price': 47.34816,
#   'gain': -0.0031471037297852475},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-02 09:50:00'),
#   'open_price': 90.09014,
#   'close_datetime': Timestamp('2016-02-02 09:51:00'),
#   'close_price': 90.01086,
#   'gain': -0.0008800075124759639},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-02 09:51:00'),
#   'open_price': 90.01086,
#   'close_datetime': Timestamp('2016-02-02 09:52:00'),
#   'close_price': 89.98802,
#   'gain': -0.00025374715895379714},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-02 09:52:00'),
#   'open_price': 89.98802,
#   'close_datetime': Timestamp('2016-02-02 09:53:00'),
#   'close_price': 89.9327,
#   'gain': -0.0006147484965221917},
#  {'ticker': 'MDLZ',
#   'open_datetime': Timestamp('2016-02-03 09:36:00'),
#   'open_price': 39.72434,
#   'close_datetime': Timestamp('2016-02-03 09:37:00'),
#   'close_price': 39.54566,
#   'gain': -0.004497997952892356},
#  {'ticker': 'ADP',
#   'open_datetime': Timestamp('2016-02-03 09:37:00'),
#   'open_price': 81.57372,
#   'close_datetime': Timestamp('2016-02-03 09:38:00'),
#   'close_price': 81.31373,
#   'gain': -0.003187178419716396},
#  {'ticker': 'ADP',
#   'open_datetime': Timestamp('2016-02-03 09:38:00'),
#   'open_price': 81.31373,
#   'close_datetime': Timestamp('2016-02-03 09:39:00'),
#   'close_price': 81.30612,
#   'gain': -9.358813081136079e-05},
#  {'ticker': 'MDLZ',
#   'open_datetime': Timestamp('2016-02-03 09:39:00'),
#   'open_price': 39.87823,
#   'close_datetime': Timestamp('2016-02-03 09:40:00'),
#   'close_price': 39.8152,
#   'gain': -0.0015805616247261927},
#  {'ticker': 'MDLZ',
#   'open_datetime': Timestamp('2016-02-03 09:40:00'),
#   'open_price': 39.8152,
#   'close_datetime': Timestamp('2016-02-03 09:41:00'),
#   'close_price': 39.84719,
#   'gain': 0.0008034619944142039},
#  {'ticker': 'ADP',
#   'open_datetime': Timestamp('2016-02-03 09:41:00'),
#   'open_price': 81.7955,
#   'close_datetime': Timestamp('2016-02-03 09:42:00'),
#   'close_price': 81.94599,
#   'gain': 0.00183983226461102},
#  {'ticker': 'ADP',
#   'open_datetime': Timestamp('2016-02-03 09:42:00'),
#   'open_price': 81.94599,
#   'close_datetime': Timestamp('2016-02-03 09:43:00'),
#   'close_price': 82.13916,
#   'gain': 0.002357284352779302},
#  {'ticker': 'PCAR',
#   'open_datetime': Timestamp('2016-02-03 09:43:00'),
#   'open_price': 46.86861,
#   'close_datetime': Timestamp('2016-02-03 09:44:00'),
#   'close_price': 46.89119,
#   'gain': 0.0004817723418724159},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-02-03 09:44:00'),
#   'open_price': 68.5046,
#   'close_datetime': Timestamp('2016-02-03 09:45:00'),
#   'close_price': 68.35574,
#   'gain': -0.0021729927625298026},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-02-03 09:45:00'),
#   'open_price': 68.35574,
#   'close_datetime': Timestamp('2016-02-03 09:46:00'),
#   'close_price': 67.72273,
#   'gain': -0.009260524427063458},
#  {'ticker': 'SIRI',
#   'open_datetime': Timestamp('2016-02-03 09:46:00'),
#   'open_price': 3.56665,
#   'close_datetime': Timestamp('2016-02-03 09:47:00'),
#   'close_price': 3.56952,
#   'gain': 0.0008046766573674754},
#  {'ticker': 'SIRI',
#   'open_datetime': Timestamp('2016-02-03 09:47:00'),
#   'open_price': 3.56952,
#   'close_datetime': Timestamp('2016-02-03 09:48:00'),
#   'close_price': 3.56083,
#   'gain': -0.0024345009973328747},
#  {'ticker': 'SIRI',
#   'open_datetime': Timestamp('2016-02-03 09:49:00'),
#   'open_price': 3.57111,
#   'close_datetime': Timestamp('2016-02-03 09:50:00'),
#   'close_price': 3.57997,
#   'gain': 0.0024810213071005563},
#  {'ticker': 'YHOO',
#   'open_datetime': Timestamp('2016-02-03 09:54:00'),
#   'open_price': 27.73822,
#   'close_datetime': Timestamp('2016-02-03 09:55:00'),
#   'close_price': 27.78942,
#   'gain': 0.001845828607603569},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-03 09:57:00'),
#   'open_price': 88.68628,
#   'close_datetime': Timestamp('2016-02-03 09:58:00'),
#   'close_price': 88.93603,
#   'gain': 0.002816106392104911},
#  {'ticker': 'ADSK',
#   'open_datetime': Timestamp('2016-02-03 10:01:00'),
#   'open_price': 48.98454,
#   'close_datetime': Timestamp('2016-02-03 10:02:00'),
#   'close_price': 48.87099,
#   'gain': -0.0023180783161381854},
#  {'ticker': 'ADSK',
#   'open_datetime': Timestamp('2016-02-03 10:02:00'),
#   'open_price': 48.87099,
#   'close_datetime': Timestamp('2016-02-03 10:03:00'),
#   'close_price': 48.71257,
#   'gain': -0.0032415958833655624},
#  {'ticker': 'MDLZ',
#   'open_datetime': Timestamp('2016-02-03 10:03:00'),
#   'open_price': 39.73342,
#   'close_datetime': Timestamp('2016-02-03 10:04:00'),
#   'close_price': 39.79653,
#   'gain': 0.0015883354616842615},
#  {'ticker': 'WDC',
#   'open_datetime': Timestamp('2016-02-03 10:04:00'),
#   'open_price': 47.47599,
#   'close_datetime': Timestamp('2016-02-03 10:05:00'),
#   'close_price': 47.74526,
#   'gain': 0.005671709004909614},
#  {'ticker': 'NFLX',
#   'open_datetime': Timestamp('2016-02-03 10:05:00'),
#   'open_price': 87.84174,
#   'close_datetime': Timestamp('2016-02-03 10:06:00'),
#   'close_price': 87.55201,
#   'gain': -0.003298318088872167},
#  {'ticker': 'ENDP',
#   'open_datetime': Timestamp('2016-02-03 10:07:00'),
#   'open_price': 53.73618,
#   'close_datetime': Timestamp('2016-02-03 10:08:00'),
#   'close_price': 53.66876,
#   'gain': -0.0012546481718648122},
#  {'ticker': 'ENDP',
#   'open_datetime': Timestamp('2016-02-03 10:08:00'),
#   'open_price': 53.66876,
#   'close_datetime': Timestamp('2016-02-03 10:09:00'),
#   'close_price': 53.67198,
#   'gain': 5.999765971859403e-05},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-03 10:09:00'),
#   'open_price': 87.13426,
#   'close_datetime': Timestamp('2016-02-03 10:10:00'),
#   'close_price': 87.27377,
#   'gain': 0.00160109238317972},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-03 10:10:00'),
#   'open_price': 87.27377,
#   'close_datetime': Timestamp('2016-02-03 10:11:00'),
#   'close_price': 87.11975,
#   'gain': -0.0017647914144192775},
#  {'ticker': 'WDC',
#   'open_datetime': Timestamp('2016-02-03 10:11:00'),
#   'open_price': 46.97781,
#   'close_datetime': Timestamp('2016-02-03 10:12:00'),
#   'close_price': 46.92624,
#   'gain': -0.0010977523217876295},
#  {'ticker': 'ALXN',
#   'open_datetime': Timestamp('2016-02-03 10:12:00'),
#   'open_price': 135.04427,
#   'close_datetime': Timestamp('2016-02-03 10:13:00'),
#   'close_price': 134.19816,
#   'gain': -0.006265426885568784},
#  {'ticker': 'ALXN',
#   'open_datetime': Timestamp('2016-02-03 10:13:00'),
#   'open_price': 134.19816,
#   'close_datetime': Timestamp('2016-02-03 10:14:00'),
#   'close_price': 134.62852,
#   'gain': 0.0032068994090530554},
#  {'ticker': 'ALXN',
#   'open_datetime': Timestamp('2016-02-03 10:14:00'),
#   'open_price': 134.62852,
#   'close_datetime': Timestamp('2016-02-03 10:15:00'),
#   'close_price': 135.36266,
#   'gain': 0.0054530793326703466},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-03 10:15:00'),
#   'open_price': 87.04234,
#   'close_datetime': Timestamp('2016-02-03 10:16:00'),
#   'close_price': 87.2205,
#   'gain': 0.002046819972900607},
#  {'ticker': 'SIRI',
#   'open_datetime': Timestamp('2016-02-03 10:29:00'),
#   'open_price': 3.51989,
#   'close_datetime': Timestamp('2016-02-03 10:30:00'),
#   'close_price': 3.50485,
#   'gain': -0.00427286079962737},
#  {'ticker': 'SIRI',
#   'open_datetime': Timestamp('2016-02-03 10:30:00'),
#   'open_price': 3.50485,
#   'close_datetime': Timestamp('2016-02-03 10:31:00'),
#   'close_price': 3.50639,
#   'gain': 0.0004393911294350169},
#  {'ticker': 'BMRN',
#   'open_datetime': Timestamp('2016-02-03 10:31:00'),
#   'open_price': 68.23883,
#   'close_datetime': Timestamp('2016-02-03 10:32:00'),
#   'close_price': 68.24811,
#   'gain': 0.00013599295298591656},
#  {'ticker': 'FB',
#   'open_datetime': Timestamp('2016-02-03 10:32:00'),
#   'open_price': 110.83965,
#   'close_datetime': Timestamp('2016-02-03 10:33:00'),
#   'close_price': 110.67367,
#   'gain': -0.0014974785647555245},
#  {'ticker': 'SIRI',
#   'open_datetime': Timestamp('2016-02-03 10:33:00'),
#   'open_price': 3.50261,
#   'close_datetime': Timestamp('2016-02-03 10:34:00'),
#   'close_price': 3.49867,
#   'gain': -0.0011248754500214442},
#  {'ticker': 'AMZN',
#   'open_datetime': Timestamp('2016-02-03 10:34:00'),
#   'open_price': 524.62922,
#   'close_datetime': Timestamp('2016-02-03 10:35:00'),
#   'close_price': 525.70738,
#   'gain': 0.0020550894973023264},
#  {'ticker': 'FB',
#   'open_datetime': Timestamp('2016-02-03 10:35:00'),
#   'open_price': 110.7921,
#   'close_datetime': Timestamp('2016-02-03 10:36:00'),
#   'close_price': 110.83138,
#   'gain': 0.00035453791380424124},
#  {'ticker': 'ADSK',
#   'open_datetime': Timestamp('2016-02-03 10:38:00'),
#   'open_price': 47.57226,
#   'close_datetime': Timestamp('2016-02-03 10:39:00'),
#   'close_price': 47.62645,
#   'gain': 0.001139109220373352},
#  {'ticker': 'SIRI',
#   'open_datetime': Timestamp('2016-02-03 11:05:00'),
#   'open_price': 3.51799,
#   'close_datetime': Timestamp('2016-02-03 11:06:00'),
#   'close_price': 3.51143,
#   'gain': -0.0018647011503728956},
#  {'ticker': 'GOOG',
#   'open_datetime': Timestamp('2016-02-04 09:37:00'),
#   'open_price': 713.02623,
#   'close_datetime': Timestamp('2016-02-04 09:38:00'),
#   'close_price': 711.19596,
#   'gain': -0.002566904165643445},
#  {'ticker': 'NFLX',
#   'open_datetime': Timestamp('2016-02-04 09:38:00'),
#   'open_price': 88.23749,
#   'close_datetime': Timestamp('2016-02-04 09:39:00'),
#   'close_price': 88.04549,
#   'gain': -0.002175945847960919},
#  {'ticker': 'SIRI',
#   'open_datetime': Timestamp('2016-02-04 09:39:00'),
#   'open_price': 3.49157,
#   'close_datetime': Timestamp('2016-02-04 09:40:00'),
#   'close_price': 3.4942,
#   'gain': 0.0007532428105409183},
#  {'ticker': 'NXPI',
#   'open_datetime': Timestamp('2016-02-04 09:40:00'),
#   'open_price': 73.76894,
#   'close_datetime': Timestamp('2016-02-04 09:41:00'),
#   'close_price': 73.96826,
#   'gain': 0.0027019501703562524},
#  {'ticker': 'GOOG',
#   'open_datetime': Timestamp('2016-02-04 09:41:00'),
#   'open_price': 714.48044,
#   'close_datetime': Timestamp('2016-02-04 09:42:00'),
#   'close_price': 711.952,
#   'gain': -0.0035388512525270054},
#  {'ticker': 'GOOG',
#   'open_datetime': Timestamp('2016-02-04 09:42:00'),
#   'open_price': 711.952,
#   'close_datetime': Timestamp('2016-02-04 09:43:00'),
#   'close_price': 710.13011,
#   'gain': -0.0025590067869744773},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-04 09:43:00'),
#   'open_price': 92.11679,
#   'close_datetime': Timestamp('2016-02-04 09:44:00'),
#   'close_price': 91.98186,
#   'gain': -0.0014647709717196737},
#  {'ticker': 'GOOG',
#   'open_datetime': Timestamp('2016-02-04 09:44:00'),
#   'open_price': 709.1529,
#   'close_datetime': Timestamp('2016-02-04 09:45:00'),
#   'close_price': 708.19362,
#   'gain': -0.00135271251094092},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-04 09:45:00'),
#   'open_price': 91.63984,
#   'close_datetime': Timestamp('2016-02-04 09:46:00'),
#   'close_price': 91.13102,
#   'gain': -0.005552388568116225},
#  {'ticker': 'GOOG',
#   'open_datetime': Timestamp('2016-02-04 09:46:00'),
#   'open_price': 706.94274,
#   'close_datetime': Timestamp('2016-02-04 09:47:00'),
#   'close_price': 706.75362,
#   'gain': -0.00026751813025196726},
#  {'ticker': 'ALXN',
#   'open_datetime': Timestamp('2016-02-04 09:47:00'),
#   'open_price': 144.44319,
#   'close_datetime': Timestamp('2016-02-04 09:48:00'),
#   'close_price': 144.71302,
#   'gain': 0.0018680700696240033},
#  {'ticker': 'GOOG',
#   'open_datetime': Timestamp('2016-02-04 09:48:00'),
#   'open_price': 708.20215,
#   'close_datetime': Timestamp('2016-02-04 09:49:00'),
#   'close_price': 710.45513,
#   'gain': 0.0031812668176735884},
#  {'ticker': 'NFLX',
#   'open_datetime': Timestamp('2016-02-04 10:02:00'),
#   'open_price': 86.74272,
#   'close_datetime': Timestamp('2016-02-04 10:03:00'),
#   'close_price': 86.76067,
#   'gain': 0.0002069337922536787},
#  {'ticker': 'CELG',
#   'open_datetime': Timestamp('2016-02-04 10:03:00'),
#   'open_price': 99.57714,
#   'close_datetime': Timestamp('2016-02-04 10:04:00'),
#   'close_price': 99.64734,
#   'gain': 0.0007049810830076042},
#  {'ticker': 'CELG',
#   'open_datetime': Timestamp('2016-02-04 10:04:00'),
#   'open_price': 99.64734,
#   'close_datetime': Timestamp('2016-02-04 10:05:00'),
#   'close_price': 99.916,
#   'gain': 0.002696108094807117},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-02-04 11:20:00'),
#   'open_price': 69.97718,
#   'close_datetime': Timestamp('2016-02-04 11:21:00'),
#   'close_price': 70.01124,
#   'gain': 0.00048673010258482334},
#  {'ticker': 'MU',
#   'open_datetime': Timestamp('2016-02-04 11:47:00'),
#   'open_price': 10.96456,
#   'close_datetime': Timestamp('2016-02-04 11:48:00'),
#   'close_price': 10.99708,
#   'gain': 0.002965919289054908},
#  {'ticker': 'SRCL',
#   'open_datetime': Timestamp('2016-02-05 09:31:00'),
#   'open_price': 110.88405,
#   'close_datetime': Timestamp('2016-02-05 09:33:00'),
#   'close_price': 111.99779,
#   'gain': 0.010044185795883112},
#  {'ticker': 'SRCL',
#   'open_datetime': Timestamp('2016-02-05 09:36:00'),
#   'open_price': 113.87918,
#   'close_datetime': Timestamp('2016-02-05 09:37:00'),
#   'close_price': 113.79213,
#   'gain': -0.000764406628147524},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-05 09:37:00'),
#   'open_price': 31.14583,
#   'close_datetime': Timestamp('2016-02-05 09:38:00'),
#   'close_price': 31.34527,
#   'gain': 0.006403425434480288},
#  {'ticker': 'ADI',
#   'open_datetime': Timestamp('2016-02-05 09:38:00'),
#   'open_price': 51.48818,
#   'close_datetime': Timestamp('2016-02-05 09:39:00'),
#   'close_price': 51.55415,
#   'gain': 0.0012812649427499686},
#  {'ticker': 'ALXN',
#   'open_datetime': Timestamp('2016-02-05 09:39:00'),
#   'open_price': 144.02944,
#   'close_datetime': Timestamp('2016-02-05 09:40:00'),
#   'close_price': 144.09,
#   'gain': 0.0004204695928832987},
#  {'ticker': 'MNST',
#   'open_datetime': Timestamp('2016-02-05 09:40:00'),
#   'open_price': 127.1141,
#   'close_datetime': Timestamp('2016-02-05 09:41:00'),
#   'close_price': 127.17979,
#   'gain': 0.0005167798064888441},
#  {'ticker': 'WDC',
#   'open_datetime': Timestamp('2016-02-05 09:41:00'),
#   'open_price': 48.51384,
#   'close_datetime': Timestamp('2016-02-05 09:42:00'),
#   'close_price': 48.43326,
#   'gain': -0.001660969323393175},
#  {'ticker': 'ADBE',
#   'open_datetime': Timestamp('2016-02-05 09:42:00'),
#   'open_price': 81.95763,
#   'close_datetime': Timestamp('2016-02-05 09:43:00'),
#   'close_price': 81.69536,
#   'gain': -0.003200068132765685},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-02-05 09:43:00'),
#   'open_price': 69.07234,
#   'close_datetime': Timestamp('2016-02-05 09:44:00'),
#   'close_price': 69.02462,
#   'gain': -0.0006908698908998626},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-02-05 09:44:00'),
#   'open_price': 69.02462,
#   'close_datetime': Timestamp('2016-02-05 09:45:00'),
#   'close_price': 68.52715,
#   'gain': -0.00720713855433022},
#  {'ticker': 'ADBE',
#   'open_datetime': Timestamp('2016-02-05 09:45:00'),
#   'open_price': 81.09279,
#   'close_datetime': Timestamp('2016-02-05 09:46:00'),
#   'close_price': 81.1115,
#   'gain': 0.00023072334790815417},
#  {'ticker': 'ADBE',
#   'open_datetime': Timestamp('2016-02-05 09:46:00'),
#   'open_price': 81.1115,
#   'close_datetime': Timestamp('2016-02-05 09:47:00'),
#   'close_price': 81.13968,
#   'gain': 0.00034742299180747334},
#  {'ticker': 'ADBE',
#   'open_datetime': Timestamp('2016-02-05 09:47:00'),
#   'open_price': 81.13968,
#   'close_datetime': Timestamp('2016-02-05 09:48:00'),
#   'close_price': 81.17053,
#   'gain': 0.00038020854901080377},
#  {'ticker': 'ADBE',
#   'open_datetime': Timestamp('2016-02-05 09:48:00'),
#   'open_price': 81.17053,
#   'close_datetime': Timestamp('2016-02-05 09:49:00'),
#   'close_price': 81.28519,
#   'gain': 0.0014125816352314152},
#  {'ticker': 'ILMN',
#   'open_datetime': Timestamp('2016-02-05 09:49:00'),
#   'open_price': 139.11125,
#   'close_datetime': Timestamp('2016-02-05 09:50:00'),
#   'close_price': 138.75824,
#   'gain': -0.002537609287530748},
#  {'ticker': 'SRCL',
#   'open_datetime': Timestamp('2016-02-05 09:50:00'),
#   'open_price': 111.72128,
#   'close_datetime': Timestamp('2016-02-05 09:51:00'),
#   'close_price': 111.56259,
#   'gain': -0.0014204097912232378},
#  {'ticker': 'SRCL',
#   'open_datetime': Timestamp('2016-02-05 09:51:00'),
#   'open_price': 111.56259,
#   'close_datetime': Timestamp('2016-02-05 09:52:00'),
#   'close_price': 112.48632,
#   'gain': 0.008279926093505056},
#  {'ticker': 'SRCL',
#   'open_datetime': Timestamp('2016-02-05 09:52:00'),
#   'open_price': 112.48632,
#   'close_datetime': Timestamp('2016-02-05 09:53:00'),
#   'close_price': 112.13407,
#   'gain': -0.003131491900526323},
#  {'ticker': 'SRCL',
#   'open_datetime': Timestamp('2016-02-05 10:26:00'),
#   'open_price': 109.77075,
#   'close_datetime': Timestamp('2016-02-05 10:27:00'),
#   'close_price': 109.70118,
#   'gain': -0.0006337753909854219},
#  {'ticker': 'SRCL',
#   'open_datetime': Timestamp('2016-02-05 10:28:00'),
#   'open_price': 109.91642,
#   'close_datetime': Timestamp('2016-02-05 10:29:00'),
#   'close_price': 110.12837,
#   'gain': 0.0019282833265494058},
#  {'ticker': 'SRCL',
#   'open_datetime': Timestamp('2016-02-05 10:29:00'),
#   'open_price': 110.12837,
#   'close_datetime': Timestamp('2016-02-05 10:30:00'),
#   'close_price': 110.43585,
#   'gain': 0.002792014446413746},
#  {'ticker': 'SRCL',
#   'open_datetime': Timestamp('2016-02-05 10:30:00'),
#   'open_price': 110.43585,
#   'close_datetime': Timestamp('2016-02-05 10:31:00'),
#   'close_price': 110.37932,
#   'gain': -0.0005118808792615358},
#  {'ticker': 'MU',
#   'open_datetime': Timestamp('2016-02-05 10:31:00'),
#   'open_price': 11.07787,
#   'close_datetime': Timestamp('2016-02-05 10:32:00'),
#   'close_price': 11.09996,
#   'gain': 0.0019940656461935923},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-05 10:32:00'),
#   'open_price': 88.32833,
#   'close_datetime': Timestamp('2016-02-05 10:33:00'),
#   'close_price': 88.45184,
#   'gain': 0.0013983056172352656},
#  {'ticker': 'BMRN',
#   'open_datetime': Timestamp('2016-02-05 10:33:00'),
#   'open_price': 68.77758,
#   'close_datetime': Timestamp('2016-02-05 10:34:00'),
#   'close_price': 68.90288,
#   'gain': 0.0018218146087721572},
#  {'ticker': 'BMRN',
#   'open_datetime': Timestamp('2016-02-05 10:59:00'),
#   'open_price': 68.34928,
#   'close_datetime': Timestamp('2016-02-05 11:00:00'),
#   'close_price': 68.36498,
#   'gain': 0.0002297024928427863},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-02-05 11:00:00'),
#   'open_price': 71.06461,
#   'close_datetime': Timestamp('2016-02-05 11:01:00'),
#   'close_price': 70.64667,
#   'gain': -0.005881127047626118},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-02-05 11:03:00'),
#   'open_price': 70.13174,
#   'close_datetime': Timestamp('2016-02-05 11:04:00'),
#   'close_price': 70.056,
#   'gain': -0.0010799675011627567},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-02-05 11:06:00'),
#   'open_price': 70.21626,
#   'close_datetime': Timestamp('2016-02-05 11:07:00'),
#   'close_price': 70.50941,
#   'gain': 0.004174958905529817},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-02-08 09:31:00'),
#   'open_price': 54.28561,
#   'close_datetime': Timestamp('2016-02-08 09:32:00'),
#   'close_price': 54.41855,
#   'gain': 0.0024488994413069125},
#  {'ticker': 'MSFT',
#   'open_datetime': Timestamp('2016-02-08 09:32:00'),
#   'open_price': 48.91054,
#   'close_datetime': Timestamp('2016-02-08 09:33:00'),
#   'close_price': 49.00626,
#   'gain': 0.001957042388000624},
#  {'ticker': 'AAL',
#   'open_datetime': Timestamp('2016-02-08 09:33:00'),
#   'open_price': 35.34931,
#   'close_datetime': Timestamp('2016-02-08 09:34:00'),
#   'close_price': 35.15448,
#   'gain': -0.0055115644407204315},
#  {'ticker': 'AMZN',
#   'open_datetime': Timestamp('2016-02-08 09:34:00'),
#   'open_price': 485.31483,
#   'close_datetime': Timestamp('2016-02-08 09:35:00'),
#   'close_price': 482.21925,
#   'gain': -0.006378498674767437},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-08 09:35:00'),
#   'open_price': 28.25517,
#   'close_datetime': Timestamp('2016-02-08 09:36:00'),
#   'close_price': 28.55491,
#   'gain': 0.01060832406954196},
#  {'ticker': 'MSFT',
#   'open_datetime': Timestamp('2016-02-08 09:36:00'),
#   'open_price': 48.50566,
#   'close_datetime': Timestamp('2016-02-08 09:37:00'),
#   'close_price': 48.28232,
#   'gain': -0.004604411114084425},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-08 09:37:00'),
#   'open_price': 28.63026,
#   'close_datetime': Timestamp('2016-02-08 09:38:00'),
#   'close_price': 28.56556,
#   'gain': -0.0022598467495579303},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-08 09:38:00'),
#   'open_price': 28.56556,
#   'close_datetime': Timestamp('2016-02-08 09:39:00'),
#   'close_price': 28.80338,
#   'gain': 0.00832541003922203},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-08 09:39:00'),
#   'open_price': 28.80338,
#   'close_datetime': Timestamp('2016-02-08 09:40:00'),
#   'close_price': 28.71159,
#   'gain': -0.0031867787738799956},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-08 09:40:00'),
#   'open_price': 28.71159,
#   'close_datetime': Timestamp('2016-02-08 09:41:00'),
#   'close_price': 28.8041,
#   'gain': 0.0032220437809260026},
#  {'ticker': 'MSFT',
#   'open_datetime': Timestamp('2016-02-08 09:41:00'),
#   'open_price': 48.8005,
#   'close_datetime': Timestamp('2016-02-08 09:42:00'),
#   'close_price': 48.79176,
#   'gain': -0.00017909652565041502},
#  {'ticker': 'ADBE',
#   'open_datetime': Timestamp('2016-02-08 09:42:00'),
#   'open_price': 75.46866,
#   'close_datetime': Timestamp('2016-02-08 09:43:00'),
#   'close_price': 75.56667,
#   'gain': 0.0012986847785557893},
#  {'ticker': 'ADBE',
#   'open_datetime': Timestamp('2016-02-08 09:43:00'),
#   'open_price': 75.56667,
#   'close_datetime': Timestamp('2016-02-08 09:44:00'),
#   'close_price': 75.32252,
#   'gain': -0.003230921780726936},
#  {'ticker': 'ADBE',
#   'open_datetime': Timestamp('2016-02-08 09:47:00'),
#   'open_price': 74.45748,
#   'close_datetime': Timestamp('2016-02-08 09:48:00'),
#   'close_price': 74.38827,
#   'gain': -0.0009295238033841357},
#  {'ticker': 'ISRG',
#   'open_datetime': Timestamp('2016-02-08 09:48:00'),
#   'open_price': 517.99,
#   'close_datetime': Timestamp('2016-02-08 09:49:00'),
#   'close_price': 520.28374,
#   'gain': 0.00442815498368686},
#  {'ticker': 'ADBE',
#   'open_datetime': Timestamp('2016-02-08 09:49:00'),
#   'open_price': 74.26243,
#   'close_datetime': Timestamp('2016-02-08 09:50:00'),
#   'close_price': 74.04543,
#   'gain': -0.002922069746438391},
#  {'ticker': 'ADBE',
#   'open_datetime': Timestamp('2016-02-08 09:50:00'),
#   'open_price': 74.04543,
#   'close_datetime': Timestamp('2016-02-08 09:51:00'),
#   'close_price': 74.05003,
#   'gain': 6.212402304923607e-05},
#  {'ticker': 'ADBE',
#   'open_datetime': Timestamp('2016-02-08 09:51:00'),
#   'open_price': 74.05003,
#   'close_datetime': Timestamp('2016-02-08 09:52:00'),
#   'close_price': 74.13734,
#   'gain': 0.0011790677194862447},
#  {'ticker': 'ADBE',
#   'open_datetime': Timestamp('2016-02-08 09:52:00'),
#   'open_price': 74.13734,
#   'close_datetime': Timestamp('2016-02-08 09:53:00'),
#   'close_price': 74.29401,
#   'gain': 0.0021132401027607064},
#  {'ticker': 'SIRI',
#   'open_datetime': Timestamp('2016-02-08 09:53:00'),
#   'open_price': 3.35284,
#   'close_datetime': Timestamp('2016-02-08 09:54:00'),
#   'close_price': 3.35015,
#   'gain': -0.0008023049116569413},
#  {'ticker': 'NXPI',
#   'open_datetime': Timestamp('2016-02-08 09:54:00'),
#   'open_price': 66.34413,
#   'close_datetime': Timestamp('2016-02-08 09:55:00'),
#   'close_price': 66.654,
#   'gain': 0.004670646822861184},
#  {'ticker': 'SIRI',
#   'open_datetime': Timestamp('2016-02-08 09:55:00'),
#   'open_price': 3.34776,
#   'close_datetime': Timestamp('2016-02-08 09:56:00'),
#   'close_price': 3.34539,
#   'gain': -0.0007079360527636339},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-08 09:56:00'),
#   'open_price': 28.80169,
#   'close_datetime': Timestamp('2016-02-08 09:57:00'),
#   'close_price': 28.74384,
#   'gain': -0.0020085626919809896},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-08 10:00:00'),
#   'open_price': 28.62232,
#   'close_datetime': Timestamp('2016-02-08 10:01:00'),
#   'close_price': 28.69207,
#   'gain': 0.0024369093770177487},
#  {'ticker': 'NXPI',
#   'open_datetime': Timestamp('2016-02-08 10:09:00'),
#   'open_price': 65.65549,
#   'close_datetime': Timestamp('2016-02-08 10:10:00'),
#   'close_price': 65.50138,
#   'gain': -0.002347252301368901},
#  {'ticker': 'CTRP',
#   'open_datetime': Timestamp('2016-02-08 10:10:00'),
#   'open_price': 37.33695,
#   'close_datetime': Timestamp('2016-02-08 10:11:00'),
#   'close_price': 37.36014,
#   'gain': 0.0006211005451703901},
#  {'ticker': 'PCLN',
#   'open_datetime': Timestamp('2016-02-08 10:11:00'),
#   'open_price': 973.16854,
#   'close_datetime': Timestamp('2016-02-08 10:12:00'),
#   'close_price': 975.58276,
#   'gain': 0.002480783030655718},
#  {'ticker': 'BIIB',
#   'open_datetime': Timestamp('2016-02-08 10:12:00'),
#   'open_price': 252.07696,
#   'close_datetime': Timestamp('2016-02-08 10:13:00'),
#   'close_price': 251.65866,
#   'gain': -0.001659413855197303},
#  {'ticker': 'FB',
#   'open_datetime': Timestamp('2016-02-08 10:13:00'),
#   'open_price': 100.82654,
#   'close_datetime': Timestamp('2016-02-08 10:14:00'),
#   'close_price': 101.1025,
#   'gain': 0.002736977783825687},
#  {'ticker': 'FB',
#   'open_datetime': Timestamp('2016-02-08 10:14:00'),
#   'open_price': 101.1025,
#   'close_datetime': Timestamp('2016-02-08 10:15:00'),
#   'close_price': 101.44568,
#   'gain': 0.0033943769936449603},
#  {'ticker': 'FB',
#   'open_datetime': Timestamp('2016-02-08 10:19:00'),
#   'open_price': 100.8441,
#   'close_datetime': Timestamp('2016-02-08 10:20:00'),
#   'close_price': 100.58059,
#   'gain': -0.002613043301492071},
#  {'ticker': 'FB',
#   'open_datetime': Timestamp('2016-02-08 10:21:00'),
#   'open_price': 100.708,
#   'close_datetime': Timestamp('2016-02-08 10:22:00'),
#   'close_price': 100.36483,
#   'gain': -0.003407574373436079},
#  {'ticker': 'FB',
#   'open_datetime': Timestamp('2016-02-08 10:22:00'),
#   'open_price': 100.36483,
#   'close_datetime': Timestamp('2016-02-08 10:23:00'),
#   'close_price': 100.45932,
#   'gain': 0.000941465252320036},
#  {'ticker': 'FB',
#   'open_datetime': Timestamp('2016-02-08 10:43:00'),
#   'open_price': 100.31878,
#   'close_datetime': Timestamp('2016-02-08 10:44:00'),
#   'close_price': 100.36589,
#   'gain': 0.00046960299955790255},
#  {'ticker': 'FB',
#   'open_datetime': Timestamp('2016-02-08 10:44:00'),
#   'open_price': 100.36589,
#   'close_datetime': Timestamp('2016-02-08 10:45:00'),
#   'close_price': 100.51078,
#   'gain': 0.0014436179462963337},
#  {'ticker': 'FB',
#   'open_datetime': Timestamp('2016-02-08 10:47:00'),
#   'open_price': 100.2703,
#   'close_datetime': Timestamp('2016-02-08 10:48:00'),
#   'close_price': 100.54734,
#   'gain': 0.0027629317953571444},
#  {'ticker': 'REGN',
#   'open_datetime': Timestamp('2016-02-08 10:57:00'),
#   'open_price': 381.61466,
#   'close_datetime': Timestamp('2016-02-08 10:58:00'),
#   'close_price': 381.13261,
#   'gain': -0.0012631852245928265},
#  {'ticker': 'AMZN',
#   'open_datetime': Timestamp('2016-02-08 11:03:00'),
#   'open_price': 481.08689,
#   'close_datetime': Timestamp('2016-02-08 11:04:00'),
#   'close_price': 480.19595,
#   'gain': -0.0018519315710307561},
#  {'ticker': 'AMZN',
#   'open_datetime': Timestamp('2016-02-08 11:13:00'),
#   'open_price': 475.83502,
#   'close_datetime': Timestamp('2016-02-08 11:14:00'),
#   'close_price': 475.73387,
#   'gain': -0.0002125736773219454},
#  {'ticker': 'REGN',
#   'open_datetime': Timestamp('2016-02-09 09:31:00'),
#   'open_price': 358.78824,
#   'close_datetime': Timestamp('2016-02-09 09:32:00'),
#   'close_price': 364.27529,
#   'gain': 0.015293282745276186},
#  {'ticker': 'ENDP',
#   'open_datetime': Timestamp('2016-02-09 09:32:00'),
#   'open_price': 49.54635,
#   'close_datetime': Timestamp('2016-02-09 09:33:00'),
#   'close_price': 49.61942,
#   'gain': 0.0014747806851564506},
#  {'ticker': 'ADSK',
#   'open_datetime': Timestamp('2016-02-09 09:33:00'),
#   'open_price': 41.70013,
#   'close_datetime': Timestamp('2016-02-09 09:34:00'),
#   'close_price': 41.67726,
#   'gain': -0.0005484395372389632},
#  {'ticker': 'WDC',
#   'open_datetime': Timestamp('2016-02-09 09:34:00'),
#   'open_price': 41.03378,
#   'close_datetime': Timestamp('2016-02-09 09:35:00'),
#   'close_price': 41.08646,
#   'gain': 0.0012838203060990794},
#  {'ticker': 'ADSK',
#   'open_datetime': Timestamp('2016-02-09 09:35:00'),
#   'open_price': 41.71949,
#   'close_datetime': Timestamp('2016-02-09 09:36:00'),
#   'close_price': 42.10726,
#   'gain': 0.009294696555494714},
#  {'ticker': 'FB',
#   'open_datetime': Timestamp('2016-02-09 09:36:00'),
#   'open_price': 98.74719,
#   'close_datetime': Timestamp('2016-02-09 09:37:00'),
#   'close_price': 98.92876,
#   'gain': 0.001838735866812955},
#  {'ticker': 'ADSK',
#   'open_datetime': Timestamp('2016-02-09 09:37:00'),
#   'open_price': 42.39225,
#   'close_datetime': Timestamp('2016-02-09 09:38:00'),
#   'close_price': 42.4684,
#   'gain': 0.0017963189026297378},
#  {'ticker': 'ADSK',
#   'open_datetime': Timestamp('2016-02-09 09:38:00'),
#   'open_price': 42.4684,
#   'close_datetime': Timestamp('2016-02-09 09:39:00'),
#   'close_price': 42.55718,
#   'gain': 0.0020904955213758903},
#  {'ticker': 'WDC',
#   'open_datetime': Timestamp('2016-02-09 09:39:00'),
#   'open_price': 41.36092,
#   'close_datetime': Timestamp('2016-02-09 09:40:00'),
#   'close_price': 41.38793,
#   'gain': 0.0006530318958088237},
#  {'ticker': 'FB',
#   'open_datetime': Timestamp('2016-02-09 10:00:00'),
#   'open_price': 101.01075,
#   'close_datetime': Timestamp('2016-02-09 10:01:00'),
#   'close_price': 101.59021,
#   'gain': 0.005736617142234835},
#  {'ticker': 'MU',
#   'open_datetime': Timestamp('2016-02-09 10:16:00'),
#   'open_price': 10.12849,
#   'close_datetime': Timestamp('2016-02-09 10:17:00'),
#   'close_price': 10.11255,
#   'gain': -0.0015737785197989763},
#  {'ticker': 'MU',
#   'open_datetime': Timestamp('2016-02-09 10:17:00'),
#   'open_price': 10.11255,
#   'close_datetime': Timestamp('2016-02-09 10:18:00'),
#   'close_price': 10.14958,
#   'gain': 0.0036617865919080423},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-09 10:18:00'),
#   'open_price': 82.42689,
#   'close_datetime': Timestamp('2016-02-09 10:19:00'),
#   'close_price': 82.42835,
#   'gain': 1.7712666339764435e-05},
#  {'ticker': 'BMRN',
#   'open_datetime': Timestamp('2016-02-09 10:19:00'),
#   'open_price': 66.2273,
#   'close_datetime': Timestamp('2016-02-09 10:20:00'),
#   'close_price': 66.4075,
#   'gain': 0.0027209323043518195},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-02-09 10:20:00'),
#   'open_price': 72.63629,
#   'close_datetime': Timestamp('2016-02-09 10:21:00'),
#   'close_price': 72.62263,
#   'gain': -0.00018806026574321954},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-09 10:21:00'),
#   'open_price': 82.22826,
#   'close_datetime': Timestamp('2016-02-09 10:22:00'),
#   'close_price': 82.54866,
#   'gain': 0.0038964706294404407},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-09 10:28:00'),
#   'open_price': 81.933,
#   'close_datetime': Timestamp('2016-02-09 10:29:00'),
#   'close_price': 81.78201,
#   'gain': -0.001842847204423215},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-09 10:30:00'),
#   'open_price': 81.59509,
#   'close_datetime': Timestamp('2016-02-09 10:31:00'),
#   'close_price': 81.30932,
#   'gain': -0.0035022940718614248},
#  {'ticker': 'NFLX',
#   'open_datetime': Timestamp('2016-02-09 10:31:00'),
#   'open_price': 86.1609,
#   'close_datetime': Timestamp('2016-02-09 10:32:00'),
#   'close_price': 86.12592,
#   'gain': -0.00040598461715237946},
#  {'ticker': 'NFLX',
#   'open_datetime': Timestamp('2016-02-09 10:32:00'),
#   'open_price': 86.12592,
#   'close_datetime': Timestamp('2016-02-09 10:33:00'),
#   'close_price': 85.95631,
#   'gain': -0.0019693258429052674},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-09 10:33:00'),
#   'open_price': 81.5516,
#   'close_datetime': Timestamp('2016-02-09 10:34:00'),
#   'close_price': 81.78359,
#   'gain': 0.0028447020046205146},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-09 10:34:00'),
#   'open_price': 81.78359,
#   'close_datetime': Timestamp('2016-02-09 10:35:00'),
#   'close_price': 81.52431,
#   'gain': -0.0031703181530671853},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-09 10:35:00'),
#   'open_price': 81.52431,
#   'close_datetime': Timestamp('2016-02-09 10:36:00'),
#   'close_price': 81.61996,
#   'gain': 0.0011732696664345423},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-09 10:36:00'),
#   'open_price': 81.61996,
#   'close_datetime': Timestamp('2016-02-09 10:37:00'),
#   'close_price': 81.81072,
#   'gain': 0.0023371734070930365},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-02-09 10:41:00'),
#   'open_price': 71.8239,
#   'close_datetime': Timestamp('2016-02-09 10:42:00'),
#   'close_price': 71.76547,
#   'gain': -0.0008135175060112486},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-09 10:42:00'),
#   'open_price': 81.39148,
#   'close_datetime': Timestamp('2016-02-09 10:43:00'),
#   'close_price': 81.61571,
#   'gain': 0.0027549566613115487},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-09 10:43:00'),
#   'open_price': 81.61571,
#   'close_datetime': Timestamp('2016-02-09 10:44:00'),
#   'close_price': 81.53117,
#   'gain': -0.001035829989103863},
#  {'ticker': 'NXPI',
#   'open_datetime': Timestamp('2016-02-09 10:44:00'),
#   'open_price': 65.16704,
#   'close_datetime': Timestamp('2016-02-09 10:45:00'),
#   'close_price': 65.16654,
#   'gain': -7.672590315631758e-06},
#  {'ticker': 'REGN',
#   'open_datetime': Timestamp('2016-02-09 10:46:00'),
#   'open_price': 372.84171,
#   'close_datetime': Timestamp('2016-02-09 10:47:00'),
#   'close_price': 372.887,
#   'gain': 0.00012147246079314116},
#  {'ticker': 'BMRN',
#   'open_datetime': Timestamp('2016-02-09 10:55:00'),
#   'open_price': 64.01158,
#   'close_datetime': Timestamp('2016-02-09 10:56:00'),
#   'close_price': 64.10328,
#   'gain': 0.0014325532973878008},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-09 10:56:00'),
#   'open_price': 80.37259,
#   'close_datetime': Timestamp('2016-02-09 10:57:00'),
#   'close_price': 80.35046,
#   'gain': -0.00027534262613664935},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-02-09 10:57:00'),
#   'open_price': 80.35046,
#   'close_datetime': Timestamp('2016-02-09 10:58:00'),
#   'close_price': 80.45482,
#   'gain': 0.001298810237054023},
#  {'ticker': 'TSLA',
#   'open_datetime': Timestamp('2016-02-09 11:55:00'),
#   'open_price': 149.79392,
#   'close_datetime': Timestamp('2016-02-09 11:56:00'),
#   'close_price': 149.61982,
#   'gain': -0.0011622634616946395},
#  {'ticker': 'TSLA',
#   'open_datetime': Timestamp('2016-02-09 11:56:00'),
#   'open_price': 149.61982,
#   'close_datetime': Timestamp('2016-02-09 11:57:00'),
#   'close_price': 149.39893,
#   'gain': -0.0014763418375987696},
#  {'ticker': 'VIAB',
#   'open_datetime': Timestamp('2016-02-10 09:34:00'),
#   'open_price': 31.69294,
#   'close_datetime': Timestamp('2016-02-10 09:35:00'),
#   'close_price': 31.56507,
#   'gain': -0.0040346525125154525},
#  {'ticker': 'VIAB',
#   'open_datetime': Timestamp('2016-02-10 09:35:00'),
#   'open_price': 31.56507,
#   'close_datetime': Timestamp('2016-02-10 09:36:00'),
#   'close_price': 31.67879,
#   'gain': 0.003602716547119988},
#  {'ticker': 'DISCA',
#   'open_datetime': Timestamp('2016-02-10 09:36:00'),
#   'open_price': 23.99285,
#   'close_datetime': Timestamp('2016-02-10 09:37:00'),
#   'close_price': 24.00854,
#   'gain': 0.000653944821061246},
#  {'ticker': 'VIAB',
#   'open_datetime': Timestamp('2016-02-10 09:37:00'),
#   'open_price': 31.66861,
#   'close_datetime': Timestamp('2016-02-10 09:38:00'),
#   'close_price': 31.18204,
#   'gain': -0.015364425530517456},
#  {'ticker': 'TSLA',
#   'open_datetime': Timestamp('2016-02-10 09:38:00'),
#   'open_price': 145.21823,
#   'close_datetime': Timestamp('2016-02-10 09:39:00'),
#   'close_price': 145.6484,
#   'gain': 0.0029622313947773905},
#  {'ticker': 'WDC',
#   'open_datetime': Timestamp('2016-02-10 09:39:00'),
#   'open_price': 39.97056,
#   'close_datetime': Timestamp('2016-02-10 09:40:00'),
#   'close_price': 39.97402,
#   'gain': 8.65637108913164e-05},
#  {'ticker': 'FB',
#   'open_datetime': Timestamp('2016-02-10 09:40:00'),
#   'open_price': 100.81826,
#   'close_datetime': Timestamp('2016-02-10 09:41:00'),
#   'close_price': 100.9581,
#   'gain': 0.0013870503220349828},
#  {'ticker': 'FB',
#   'open_datetime': Timestamp('2016-02-10 09:44:00'),
#   'open_price': 100.33478,
#   'close_datetime': Timestamp('2016-02-10 09:45:00'),
#   'close_price': 100.46439,
#   'gain': 0.0012917753943348415},
#  {'ticker': 'NXPI',
#   'open_datetime': Timestamp('2016-02-10 09:45:00'),
#   'open_price': 65.96002,
#   'close_datetime': Timestamp('2016-02-10 09:46:00'),
#   'close_price': 66.03931,
#   'gain': 0.001202091812585871},
#  {'ticker': 'ADBE',
#   'open_datetime': Timestamp('2016-02-10 09:46:00'),
#   'open_price': 74.79772,
#   'close_datetime': Timestamp('2016-02-10 09:47:00'),
#   'close_price': 74.95811,
#   'gain': 0.002144316698423517},
#  {'ticker': 'CHTR',
#   'open_datetime': Timestamp('2016-02-10 09:47:00'),
#   'open_price': 166.0524,
#   'close_datetime': Timestamp('2016-02-10 09:48:00'),
#   'close_price': 165.81073,
#   'gain': -0.0014553839631345235},
#  {'ticker': 'TSLA',
#   'open_datetime': Timestamp('2016-02-10 10:41:00'),
#   'open_price': 151.99859,
#   'close_datetime': Timestamp('2016-02-10 10:42:00'),
#   'close_price': 151.38738,
#   'gain': -0.0040211557225629515},
#  {'ticker': 'MU',
#   'open_datetime': Timestamp('2016-02-10 10:43:00'),
#   'open_price': 10.04508,
#   'close_datetime': Timestamp('2016-02-10 10:44:00'),
#   'close_price': 10.05984,
#   'gain': 0.0014693760527540842},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-02-10 10:59:00'),
#   'open_price': 73.36259,
#   'close_datetime': Timestamp('2016-02-10 11:00:00'),
#   'close_price': 73.50971,
#   'gain': 0.0020053817620125057},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-02-10 11:41:00'),
#   'open_price': 73.31,
#   'close_datetime': Timestamp('2016-02-10 11:42:00'),
#   'close_price': 73.43125,
#   'gain': 0.0016539353430637485},
#  {'ticker': 'SIRI',
#   'open_datetime': Timestamp('2016-02-11 09:31:00'),
#   'open_price': 3.34219,
#   'close_datetime': Timestamp('2016-02-11 09:32:00'),
#   'close_price': 3.36818,
#   'gain': 0.00777633826921874},
#  {'ticker': 'VIAB',
#   'open_datetime': Timestamp('2016-02-11 09:32:00'),
#   'open_price': 30.34099,
#   'close_datetime': Timestamp('2016-02-11 09:33:00'),
#   'close_price': 30.4788,
#   'gain': 0.004542040322349343},
#  {'ticker': 'FAST',
#   'open_datetime': Timestamp('2016-02-11 09:33:00'),
#   'open_price': 41.04184,
#   'close_datetime': Timestamp('2016-02-11 09:34:00'),
#   'close_price': 41.03261,
#   'gain': -0.00022489245121569334},
#  {'ticker': 'MYL',
#   'open_datetime': Timestamp('2016-02-11 09:34:00'),
#   'open_price': 42.99912,
#   'close_datetime': Timestamp('2016-02-11 09:35:00'),
#   'close_price': 42.96587,
#   'gain': -0.0007732716390473884},
#  {'ticker': 'LMCA',
#   'open_datetime': Timestamp('2016-02-11 09:35:00'),
#   'open_price': 32.05,
#   'close_datetime': Timestamp('2016-02-11 09:36:00'),
#   'close_price': 32.00094,
#   'gain': -0.0015307332293290864},
#  {'ticker': 'DLTR',
#   'open_datetime': Timestamp('2016-02-11 09:36:00'),
#   'open_price': 73.95197,
#   'close_datetime': Timestamp('2016-02-11 09:37:00'),
#   'close_price': 73.96971,
#   'gain': 0.00023988542833954822},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-02-11 09:37:00'),
#   'open_price': 55.6768,
#   'close_datetime': Timestamp('2016-02-11 09:38:00'),
#   'close_price': 55.77653,
#   'gain': 0.0017912308178631132},
#  {'ticker': 'VRSK',
#   'open_datetime': Timestamp('2016-02-11 09:38:00'),
#   'open_price': 65.84,
#   'close_datetime': Timestamp('2016-02-11 09:39:00'),
#   'close_price': 65.94592,
#   'gain': 0.0016087484811664271},
#  {'ticker': 'VRSK',
#   'open_datetime': Timestamp('2016-02-11 09:39:00'),
#   'open_price': 65.94592,
#   'close_datetime': Timestamp('2016-02-11 09:40:00'),
#   'close_price': 65.9016,
#   'gain': -0.0006720658381898232},
#  {'ticker': 'VRSK',
#   'open_datetime': Timestamp('2016-02-11 09:40:00'),
#   'open_price': 65.9016,
#   'close_datetime': Timestamp('2016-02-11 09:41:00'),
#   'close_price': 66.09746,
#   'gain': 0.0029720067494567073},
#  {'ticker': 'GILD',
#   'open_datetime': Timestamp('2016-02-11 09:41:00'),
#   'open_price': 87.06264,
#   'close_datetime': Timestamp('2016-02-11 09:42:00'),
#   'close_price': 87.0666,
#   'gain': 4.5484492544588496e-05},
#  {'ticker': 'GILD',
#   'open_datetime': Timestamp('2016-02-11 09:42:00'),
#   'open_price': 87.0666,
#   'close_datetime': Timestamp('2016-02-11 09:43:00'),
#   'close_price': 87.14905,
#   'gain': 0.0009469762227996565},
#  {'ticker': 'GILD',
#   'open_datetime': Timestamp('2016-02-11 09:43:00'),
#   'open_price': 87.14905,
#   'close_datetime': Timestamp('2016-02-11 09:44:00'),
#   'close_price': 87.11337,
#   'gain': -0.00040941352774355276},
#  {'ticker': 'GILD',
#   'open_datetime': Timestamp('2016-02-11 09:44:00'),
#   'open_price': 87.11337,
#   'close_datetime': Timestamp('2016-02-11 09:45:00'),
#   'close_price': 87.29098,
#   'gain': 0.002038837436779238},
#  {'ticker': 'NFLX',
#   'open_datetime': Timestamp('2016-02-11 09:45:00'),
#   'open_price': 86.4901,
#   'close_datetime': Timestamp('2016-02-11 09:46:00'),
#   'close_price': 85.63658,
#   'gain': -0.009868412685382525},
#  {'ticker': 'NFLX',
#   'open_datetime': Timestamp('2016-02-11 09:47:00'),
#   'open_price': 85.78152,
#   'close_datetime': Timestamp('2016-02-11 09:48:00'),
#   'close_price': 85.6706,
#   'gain': -0.0012930523963670408},
#  {'ticker': 'TRIP',
#   'open_datetime': Timestamp('2016-02-11 10:22:00'),
#   'open_price': 62.73411,
#   'close_datetime': Timestamp('2016-02-11 10:23:00'),
#   'close_price': 62.70684,
#   'gain': -0.00043469174903416116},
#  {'ticker': 'EXPE',
#   'open_datetime': Timestamp('2016-02-11 11:14:00'),
#   'open_price': 102.32664,
#   'close_datetime': Timestamp('2016-02-11 11:15:00'),
#   'close_price': 102.46791,
#   'gain': 0.0013805788991019914},
#  {'ticker': 'MYL',
#   'open_datetime': Timestamp('2016-02-11 11:31:00'),
#   'open_price': 40.88445,
#   'close_datetime': Timestamp('2016-02-11 11:32:00'),
#   'close_price': 41.00354,
#   'gain': 0.002912843391558402},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-12 09:31:00'),
#   'open_price': 28.64624,
#   'close_datetime': Timestamp('2016-02-12 09:32:00'),
#   'close_price': 28.67084,
#   'gain': 0.0008587514452158297},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-12 09:32:00'),
#   'open_price': 28.67084,
#   'close_datetime': Timestamp('2016-02-12 09:33:00'),
#   'close_price': 28.81858,
#   'gain': 0.005152970753560148},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-12 09:33:00'),
#   'open_price': 28.81858,
#   'close_datetime': Timestamp('2016-02-12 09:34:00'),
#   'close_price': 28.66677,
#   'gain': -0.005267782104461813},
#  {'ticker': 'TRIP',
#   'open_datetime': Timestamp('2016-02-12 09:35:00'),
#   'open_price': 59.56341,
#   'close_datetime': Timestamp('2016-02-12 09:36:00'),
#   'close_price': 59.89325,
#   'gain': 0.0055376278826213},
#  {'ticker': 'TRIP',
#   'open_datetime': Timestamp('2016-02-12 09:36:00'),
#   'open_price': 59.89325,
#   'close_datetime': Timestamp('2016-02-12 09:37:00'),
#   'close_price': 59.5286,
#   'gain': -0.006088332157630527},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-12 09:37:00'),
#   'open_price': 28.21887,
#   'close_datetime': Timestamp('2016-02-12 09:38:00'),
#   'close_price': 27.99601,
#   'gain': -0.007897552240752403},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-12 09:38:00'),
#   'open_price': 27.99601,
#   'close_datetime': Timestamp('2016-02-12 09:39:00'),
#   'close_price': 27.89229,
#   'gain': -0.0037048136502308418},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-12 09:39:00'),
#   'open_price': 27.89229,
#   'close_datetime': Timestamp('2016-02-12 09:40:00'),
#   'close_price': 27.92525,
#   'gain': 0.0011816885598134542},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-12 09:40:00'),
#   'open_price': 27.92525,
#   'close_datetime': Timestamp('2016-02-12 09:41:00'),
#   'close_price': 27.93996,
#   'gain': 0.0005267634130402016},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-12 09:41:00'),
#   'open_price': 27.93996,
#   'close_datetime': Timestamp('2016-02-12 09:42:00'),
#   'close_price': 27.92996,
#   'gain': -0.0003579103191270857},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-12 09:42:00'),
#   'open_price': 27.92996,
#   'close_datetime': Timestamp('2016-02-12 09:43:00'),
#   'close_price': 27.86251,
#   'gain': -0.002414969444997447},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-12 09:43:00'),
#   'open_price': 27.86251,
#   'close_datetime': Timestamp('2016-02-12 09:44:00'),
#   'close_price': 27.67436,
#   'gain': -0.0067528015243422165},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-12 09:44:00'),
#   'open_price': 27.67436,
#   'close_datetime': Timestamp('2016-02-12 09:45:00'),
#   'close_price': 27.53949,
#   'gain': -0.004873464101789504},
#  {'ticker': 'ATVI',
#   'open_datetime': Timestamp('2016-02-12 09:45:00'),
# ...
#   'close_price': 93.45163,
#   'gain': -0.0011087552867093749},
#  {'ticker': 'EBAY',
#   'open_datetime': Timestamp('2016-10-03 09:59:00'),
#   'open_price': 32.46208,
#   'close_datetime': Timestamp('2016-10-03 10:00:00'),
#   'close_price': 32.41249,
#   'gain': -0.0015276285438271984},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-10-03 10:00:00'),
#   'open_price': 93.61256,
#   'close_datetime': Timestamp('2016-10-03 10:01:00'),
#   'close_price': 93.67521,
#   'gain': 0.000669247801790753},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-10-03 10:01:00'),
#   'open_price': 93.67521,
#   'close_datetime': Timestamp('2016-10-03 10:02:00'),
#   'close_price': 93.6399,
#   'gain': -0.00037694070821949285},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-10-03 10:02:00'),
#   'open_price': 93.6399,
#   'close_datetime': Timestamp('2016-10-03 10:03:00'),
#   'close_price': 93.60473,
#   'gain': -0.0003755877569283362},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-10-03 10:03:00'),
#   'open_price': 93.60473,
#   'close_datetime': Timestamp('2016-10-03 10:04:00'),
#   'close_price': 93.59092,
#   'gain': -0.00014753527946725063},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 10:04:00'),
#   'open_price': 50.83398,
#   'close_datetime': Timestamp('2016-10-03 10:05:00'),
#   'close_price': 50.84203,
#   'gain': 0.0001583586412081905},
#  {'ticker': 'TSLA',
#   'open_datetime': Timestamp('2016-10-03 10:05:00'),
#   'open_price': 213.39368,
#   'close_datetime': Timestamp('2016-10-03 10:06:00'),
#   'close_price': 213.67681,
#   'gain': 0.0013267965574238184},
#  {'ticker': 'TSLA',
#   'open_datetime': Timestamp('2016-10-03 10:06:00'),
#   'open_price': 213.67681,
#   'close_datetime': Timestamp('2016-10-03 10:07:00'),
#   'close_price': 214.03268,
#   'gain': 0.0016654591576877721},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 10:07:00'),
#   'open_price': 50.949,
#   'close_datetime': Timestamp('2016-10-03 10:08:00'),
#   'close_price': 50.98253,
#   'gain': 0.0006581090894816179},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 10:08:00'),
#   'open_price': 50.98253,
#   'close_datetime': Timestamp('2016-10-03 10:09:00'),
#   'close_price': 51.05098,
#   'gain': 0.0013426167748051279},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 10:09:00'),
#   'open_price': 51.05098,
#   'close_datetime': Timestamp('2016-10-03 10:10:00'),
#   'close_price': 51.17743,
#   'gain': 0.0024769358002529706},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-10-03 10:10:00'),
#   'open_price': 93.87721,
#   'close_datetime': Timestamp('2016-10-03 10:11:00'),
#   'close_price': 93.76576,
#   'gain': -0.0011871890952021788},
#  {'ticker': 'TSLA',
#   'open_datetime': Timestamp('2016-10-03 10:11:00'),
#   'open_price': 214.60281,
#   'close_datetime': Timestamp('2016-10-03 10:12:00'),
#   'close_price': 215.10033,
#   'gain': 0.002318329382546336},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 10:12:00'),
#   'open_price': 50.99235,
#   'close_datetime': Timestamp('2016-10-03 10:13:00'),
#   'close_price': 50.90856,
#   'gain': -0.0016431876546187903},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-10-03 10:13:00'),
#   'open_price': 93.51925,
#   'close_datetime': Timestamp('2016-10-03 10:14:00'),
#   'close_price': 93.63218,
#   'gain': 0.0012075588715692838},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-10-03 10:14:00'),
#   'open_price': 93.63218,
#   'close_datetime': Timestamp('2016-10-03 10:15:00'),
#   'close_price': 93.91088,
#   'gain': 0.0029765407576754126},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 10:15:00'),
#   'open_price': 50.99998,
#   'close_datetime': Timestamp('2016-10-03 10:16:00'),
#   'close_price': 50.9858,
#   'gain': -0.00027803932472136633},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-10-03 10:16:00'),
#   'open_price': 93.85189,
#   'close_datetime': Timestamp('2016-10-03 10:17:00'),
#   'close_price': 93.97696,
#   'gain': 0.001332631660374746},
#  {'ticker': 'TSLA',
#   'open_datetime': Timestamp('2016-10-03 10:17:00'),
#   'open_price': 214.54772,
#   'close_datetime': Timestamp('2016-10-03 10:18:00'),
#   'close_price': 213.98546,
#   'gain': -0.002620675717271706},
#  {'ticker': 'TSLA',
#   'open_datetime': Timestamp('2016-10-03 10:18:00'),
#   'open_price': 213.98546,
#   'close_datetime': Timestamp('2016-10-03 10:19:00'),
#   'close_price': 213.81797,
#   'gain': -0.0007827167322489416},
#  {'ticker': 'TSLA',
#   'open_datetime': Timestamp('2016-10-03 10:19:00'),
#   'open_price': 213.81797,
#   'close_datetime': Timestamp('2016-10-03 10:20:00'),
#   'close_price': 213.83234,
#   'gain': 6.72066992310578e-05},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 10:20:00'),
#   'open_price': 50.8238,
#   'close_datetime': Timestamp('2016-10-03 10:21:00'),
#   'close_price': 50.7767,
#   'gain': -0.0009267311771256845},
#  {'ticker': 'ILMN',
#   'open_datetime': Timestamp('2016-10-03 10:21:00'),
#   'open_price': 180.39531,
#   'close_datetime': Timestamp('2016-10-03 10:22:00'),
#   'close_price': 180.42864,
#   'gain': 0.00018476090093476666},
#  {'ticker': 'ILMN',
#   'open_datetime': Timestamp('2016-10-03 10:22:00'),
#   'open_price': 180.42864,
#   'close_datetime': Timestamp('2016-10-03 10:23:00'),
#   'close_price': 180.85673,
#   'gain': 0.002372627760204796},
#  {'ticker': 'NVDA',
#   'open_datetime': Timestamp('2016-10-03 10:23:00'),
#   'open_price': 68.54526,
#   'close_datetime': Timestamp('2016-10-03 10:24:00'),
#   'close_price': 68.52186,
#   'gain': -0.00034138027924899845},
#  {'ticker': 'VRTX',
#   'open_datetime': Timestamp('2016-10-03 10:24:00'),
#   'open_price': 85.39097,
#   'close_datetime': Timestamp('2016-10-03 10:25:00'),
#   'close_price': 85.38732,
#   'gain': -4.2744566550693474e-05},
#  {'ticker': 'NVDA',
#   'open_datetime': Timestamp('2016-10-03 10:25:00'),
#   'open_price': 68.54895,
#   'close_datetime': Timestamp('2016-10-03 10:26:00'),
#   'close_price': 68.59036,
#   'gain': 0.000604093862852736},
#  {'ticker': 'BMRN',
#   'open_datetime': Timestamp('2016-10-03 10:26:00'),
#   'open_price': 92.22799,
#   'close_datetime': Timestamp('2016-10-03 10:27:00'),
#   'close_price': 92.28342,
#   'gain': 0.0006010106042645101},
#  {'ticker': 'ILMN',
#   'open_datetime': Timestamp('2016-10-03 10:27:00'),
#   'open_price': 180.41386,
#   'close_datetime': Timestamp('2016-10-03 10:28:00'),
#   'close_price': 180.31464,
#   'gain': -0.0005499577471487087},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 10:28:00'),
#   'open_price': 50.8025,
#   'close_datetime': Timestamp('2016-10-03 10:29:00'),
#   'close_price': 50.86434,
#   'gain': 0.001217262929973851},
#  {'ticker': 'ILMN',
#   'open_datetime': Timestamp('2016-10-03 10:29:00'),
#   'open_price': 180.49811,
#   'close_datetime': Timestamp('2016-10-03 10:30:00'),
#   'close_price': 180.56437,
#   'gain': 0.00036709525656528904},
#  {'ticker': 'WDC',
#   'open_datetime': Timestamp('2016-10-03 10:30:00'),
#   'open_price': 58.77216,
#   'close_datetime': Timestamp('2016-10-03 10:31:00'),
#   'close_price': 58.84612,
#   'gain': 0.001258418952102485},
#  {'ticker': 'INCY',
#   'open_datetime': Timestamp('2016-10-03 10:31:00'),
#   'open_price': 93.89798,
#   'close_datetime': Timestamp('2016-10-03 10:32:00'),
#   'close_price': 94.08645,
#   'gain': 0.002007178429184475},
#  {'ticker': 'ILMN',
#   'open_datetime': Timestamp('2016-10-03 10:32:00'),
#   'open_price': 180.97707,
#   'close_datetime': Timestamp('2016-10-03 10:33:00'),
#   'close_price': 180.78603,
#   'gain': -0.0010556033424565154},
#  {'ticker': 'ILMN',
#   'open_datetime': Timestamp('2016-10-03 10:33:00'),
#   'open_price': 180.78603,
#   'close_datetime': Timestamp('2016-10-03 10:34:00'),
#   'close_price': 180.86003,
#   'gain': 0.00040932366289576607},
#  {'ticker': 'ILMN',
#   'open_datetime': Timestamp('2016-10-03 10:34:00'),
#   'open_price': 180.86003,
#   'close_datetime': Timestamp('2016-10-03 10:35:00'),
#   'close_price': 181.0015,
#   'gain': 0.0007822071023652833},
#  {'ticker': 'ILMN',
#   'open_datetime': Timestamp('2016-10-03 10:35:00'),
#   'open_price': 181.0015,
#   'close_datetime': Timestamp('2016-10-03 10:36:00'),
#   'close_price': 180.97124,
#   'gain': -0.00016718093496461854},
#  {'ticker': 'ILMN',
#   'open_datetime': Timestamp('2016-10-03 10:36:00'),
#   'open_price': 180.97124,
#   'close_datetime': Timestamp('2016-10-03 10:37:00'),
#   'close_price': 181.01698,
#   'gain': 0.0002527473426164014},
#  {'ticker': 'ILMN',
#   'open_datetime': Timestamp('2016-10-03 10:37:00'),
#   'open_price': 181.01698,
#   'close_datetime': Timestamp('2016-10-03 10:38:00'),
#   'close_price': 181.18617,
#   'gain': 0.0009346636984000872},
#  {'ticker': 'ILMN',
#   'open_datetime': Timestamp('2016-10-03 10:38:00'),
#   'open_price': 181.18617,
#   'close_datetime': Timestamp('2016-10-03 10:39:00'),
#   'close_price': 181.04743,
#   'gain': -0.0007657317332775053},
#  {'ticker': 'TSLA',
#   'open_datetime': Timestamp('2016-10-03 10:39:00'),
#   'open_price': 213.92638,
#   'close_datetime': Timestamp('2016-10-03 10:40:00'),
#   'close_price': 213.81498,
#   'gain': -0.0005207398919198431},
#  {'ticker': 'ILMN',
#   'open_datetime': Timestamp('2016-10-03 10:40:00'),
#   'open_price': 181.05308,
#   'close_datetime': Timestamp('2016-10-03 10:41:00'),
#   'close_price': 181.32174,
#   'gain': 0.0014838742317999298},
#  {'ticker': 'TSLA',
#   'open_datetime': Timestamp('2016-10-03 10:41:00'),
#   'open_price': 213.55719,
#   'close_datetime': Timestamp('2016-10-03 10:42:00'),
#   'close_price': 213.8023,
#   'gain': 0.0011477487599458069},
#  {'ticker': 'TSLA',
#   'open_datetime': Timestamp('2016-10-03 10:42:00'),
#   'open_price': 213.8023,
#   'close_datetime': Timestamp('2016-10-03 10:43:00'),
#   'close_price': 213.98876,
#   'gain': 0.0008721140979307096},
#  {'ticker': 'TSLA',
#   'open_datetime': Timestamp('2016-10-03 10:43:00'),
#   'open_price': 213.98876,
#   'close_datetime': Timestamp('2016-10-03 10:44:00'),
#   'close_price': 214.05374,
#   'gain': 0.0003036608091004003},
#  {'ticker': 'MAT',
#   'open_datetime': Timestamp('2016-10-03 10:44:00'),
#   'open_price': 30.5282,
#   'close_datetime': Timestamp('2016-10-03 10:45:00'),
#   'close_price': 30.56011,
#   'gain': 0.0010452630682452105},
#  {'ticker': 'MAT',
#   'open_datetime': Timestamp('2016-10-03 10:45:00'),
#   'open_price': 30.56011,
#   'close_datetime': Timestamp('2016-10-03 10:46:00'),
#   'close_price': 30.60726,
#   'gain': 0.001542860938654948},
#  {'ticker': 'VIAB',
#   'open_datetime': Timestamp('2016-10-03 10:46:00'),
#   'open_price': 37.72135,
#   'close_datetime': Timestamp('2016-10-03 10:47:00'),
#   'close_price': 37.6991,
#   'gain': -0.0005898516357447349},
#  {'ticker': 'LBTYA',
#   'open_datetime': Timestamp('2016-10-03 10:47:00'),
#   'open_price': 34.10311,
#   'close_datetime': Timestamp('2016-10-03 10:48:00'),
#   'close_price': 34.05423,
#   'gain': -0.0014333003646882655},
#  {'ticker': 'MAT',
#   'open_datetime': Timestamp('2016-10-03 10:48:00'),
#   'open_price': 30.64434,
#   'close_datetime': Timestamp('2016-10-03 10:49:00'),
#   'close_price': 30.68256,
#   'gain': 0.0012472123726599768},
#  {'ticker': 'VIAB',
#   'open_datetime': Timestamp('2016-10-03 10:49:00'),
#   'open_price': 37.706,
#   'close_datetime': Timestamp('2016-10-03 10:50:00'),
#   'close_price': 37.73203,
#   'gain': 0.0006903410597782492},
#  {'ticker': 'MAT',
#   'open_datetime': Timestamp('2016-10-03 10:50:00'),
#   'open_price': 30.65272,
#   'close_datetime': Timestamp('2016-10-03 10:51:00'),
#   'close_price': 30.65688,
#   'gain': 0.0001357138942319763},
#  {'ticker': 'MAT',
#   'open_datetime': Timestamp('2016-10-03 10:51:00'),
#   'open_price': 30.65688,
#   'close_datetime': Timestamp('2016-10-03 10:52:00'),
#   'close_price': 30.66009,
#   'gain': 0.00010470732833867206},
#  {'ticker': 'MAT',
#   'open_datetime': Timestamp('2016-10-03 10:52:00'),
#   'open_price': 30.66009,
#   'close_datetime': Timestamp('2016-10-03 10:53:00'),
#   'close_price': 30.64784,
#   'gain': -0.0003995422061710076},
#  {'ticker': 'ILMN',
#   'open_datetime': Timestamp('2016-10-03 10:53:00'),
#   'open_price': 181.97371,
#   'close_datetime': Timestamp('2016-10-03 10:54:00'),
#   'close_price': 181.79195,
#   'gain': -0.000998825599587968},
#  {'ticker': 'REGN',
#   'open_datetime': Timestamp('2016-10-03 10:54:00'),
#   'open_price': 404.92817,
#   'close_datetime': Timestamp('2016-10-03 10:55:00'),
#   'close_price': 404.94595,
#   'gain': 4.3909022185241575e-05},
#  {'ticker': 'REGN',
#   'open_datetime': Timestamp('2016-10-03 10:55:00'),
#   'open_price': 404.94595,
#   'close_datetime': Timestamp('2016-10-03 10:56:00'),
#   'close_price': 405.49804,
#   'gain': 0.0013633671357869393},
#  {'ticker': 'BMRN',
#   'open_datetime': Timestamp('2016-10-03 10:56:00'),
#   'open_price': 92.86848,
#   'close_datetime': Timestamp('2016-10-03 10:57:00'),
#   'close_price': 92.90686,
#   'gain': 0.0004132726195151403},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 10:57:00'),
#   'open_price': 50.91279,
#   'close_datetime': Timestamp('2016-10-03 10:58:00'),
#   'close_price': 50.88149,
#   'gain': -0.0006147767584530657},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 10:58:00'),
#   'open_price': 50.88149,
#   'close_datetime': Timestamp('2016-10-03 10:59:00'),
#   'close_price': 50.90326,
#   'gain': 0.0004278569672390415},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 10:59:00'),
#   'open_price': 50.90326,
#   'close_datetime': Timestamp('2016-10-03 11:00:00'),
#   'close_price': 50.90058,
#   'gain': -5.264888732087341e-05},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 11:00:00'),
#   'open_price': 50.90058,
#   'close_datetime': Timestamp('2016-10-03 11:01:00'),
#   'close_price': 50.93001,
#   'gain': 0.0005781859460148579},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 11:01:00'),
#   'open_price': 50.93001,
#   'close_datetime': Timestamp('2016-10-03 11:02:00'),
#   'close_price': 50.82074,
#   'gain': -0.002145493393777111},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 11:02:00'),
#   'open_price': 50.82074,
#   'close_datetime': Timestamp('2016-10-03 11:03:00'),
#   'close_price': 50.74852,
#   'gain': -0.0014210733649293872},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 11:03:00'),
#   'open_price': 50.74852,
#   'close_datetime': Timestamp('2016-10-03 11:04:00'),
#   'close_price': 50.75545,
#   'gain': 0.00013655570645220984},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 11:04:00'),
#   'open_price': 50.75545,
#   'close_datetime': Timestamp('2016-10-03 11:05:00'),
#   'close_price': 50.68079,
#   'gain': -0.001470975038148642},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 11:05:00'),
#   'open_price': 50.68079,
#   'close_datetime': Timestamp('2016-10-03 11:06:00'),
#   'close_price': 50.74357,
#   'gain': 0.0012387336503633132},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 11:06:00'),
#   'open_price': 50.74357,
#   'close_datetime': Timestamp('2016-10-03 11:07:00'),
#   'close_price': 50.71827,
#   'gain': -0.0004985853380044296},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 11:07:00'),
#   'open_price': 50.71827,
#   'close_datetime': Timestamp('2016-10-03 11:08:00'),
#   'close_price': 50.74512,
#   'gain': 0.0005293950286554165},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 11:08:00'),
#   'open_price': 50.74512,
#   'close_datetime': Timestamp('2016-10-03 11:09:00'),
#   'close_price': 50.78277,
#   'gain': 0.0007419432646922363},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 11:09:00'),
#   'open_price': 50.78277,
#   'close_datetime': Timestamp('2016-10-03 11:10:00'),
#   'close_price': 50.85199,
#   'gain': 0.0013630607389081256},
#  {'ticker': 'CTSH',
#   'open_datetime': Timestamp('2016-10-03 11:10:00'),
#   'open_price': 50.85199,
#   'close_datetime': Timestamp('2016-10-03 11:11:00'),
#   'close_price': 50.8861,
#   'gain': 0.0006707702097793677},
#  {'ticker': 'EBAY',
#   'open_datetime': Timestamp('2016-10-03 11:11:00'),
#   'open_price': 32.55278,
#   'close_datetime': Timestamp('2016-10-03 11:12:00'),
#   'close_price': 32.57034,
#   'gain': 0.0005394316552995821},
#  {'ticker': 'EBAY',
#   'open_datetime': Timestamp('2016-10-03 11:12:00'),
#   'open_price': 32.57034,
#   'close_datetime': Timestamp('2016-10-03 11:13:00'),
#   'close_price': 32.57527,
#   'gain': 0.0001513647078907268},
#  ...]
